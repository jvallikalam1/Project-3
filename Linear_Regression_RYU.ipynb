# %%
# Initial imports
import pandas as pd
import seaborn as sns
import numpy as np
from pathlib import Path
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\jalex\anaconda3\envs\mlenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# 1. Weather DataFrame from NYC. 
weather_df = pd.read_csv(Path('weather_nyc_final.csv'), parse_dates=True, index_col='date')
weather_df.sort_index(ascending=True, inplace=True)

weather_df.head()
# Out:
#             temp_diff
# date
# 2010-01-01        3.5
# 2010-01-02       -7.5
# 2010-01-03      -12.0
# 2010-01-04       -6.5
# 2010-01-05       -6.0

# %%
# 2. Crypto DataFrame
crypto_df = pd.read_csv(Path('crypto.csv'), parse_dates=True, index_col='Date')
crypto_df.sort_index(ascending=True, inplace=True)

crypto_df.head()
# Out:
#             BTC Volume  BTC Daily Volume Change (%)  BTC New Coins Mined  \
# Date
# 2009-01-03         0.0                          NaN                  NaN
# 2009-01-04         0.0                          NaN                  0.0
# 2009-01-05         0.0                          NaN                  0.0
# 2009-01-06         0.0                          NaN                  0.0
# 2009-01-07         0.0                          NaN                  0.0
#
#             BTC New Coins Mined (%)  BTC Active Addresses  \
# Date
# 2009-01-03                      NaN                     0
# 2009-01-04                      NaN                     0
# 2009-01-05                      NaN                     0
# 2009-01-06                      NaN                     0
# 2009-01-07                      NaN                     0
#
#             BTC Daily Active Addresses Change (%)  BTC Transactions  \
# Date
# 2009-01-03                                    NaN                 0
# 2009-01-04                                    NaN                 0
# 2009-01-05                                    NaN                 0
# 2009-01-06                                    NaN                 0
# 2009-01-07                                    NaN                 0
#
#             BTC Daily Transactions Change (%)
# Date
# 2009-01-03                                NaN
# 2009-01-04                                NaN
# 2009-01-05                                NaN
# 2009-01-06                                NaN
# 2009-01-07                                NaN

# %%
# 3. Energy Stock Ticker
stock_energy_df = pd.read_csv(Path('stocks_final.csv'), parse_dates=True, index_col='Date')
stock_energy_df.sort_index(ascending=True, inplace=True)
stock_energy_df.head()
# Out:
#             icln_Open  icln_High  icln_Low  icln_Close  icln_Adj_Close  \
# Date
# 2013-10-24      10.99      11.18     10.85       10.90        9.143383
# 2013-10-25      10.84      10.84     10.67       10.73        9.000779
# 2013-10-28      10.75      10.75     10.54       10.62        8.908505
# 2013-10-29      10.58      10.70     10.58       10.70        8.975615
# 2013-10-30      10.65      10.68     10.60       10.62        8.908505
#
#             icln_Volume  icln_pctChange   xlu_Open   xlu_High    xlu_Low  ...  \
# Date                                                                      ...
# 2013-10-24        41600       -0.004566  39.009998  39.009998  38.590000  ...
# 2013-10-25        17200       -0.015596  38.759998  39.230000  38.599998  ...
# 2013-10-28        57200       -0.010252  39.180000  39.349998  38.980000  ...
# 2013-10-29        22900        0.007533  39.110001  39.270000  39.020000  ...
# 2013-10-30        17100       -0.007477  39.240002  39.450001  38.880001  ...
#
#             ryu_Adj_Close  ryu_Volume  ryu_pctChange  futy_Open  futy_High  \
# Date
# 2013-10-24      50.859299        7100      -0.001546  25.250000  25.290001
# 2013-10-25      51.458099        5400       0.011774  25.240000  25.510000
# 2013-10-28      51.402939        2900      -0.001072  25.530001  25.600000
# 2013-10-29      51.505379        5700       0.001993  25.709999  25.709999
# 2013-10-30      51.166584        2800      -0.006578  25.590000  25.690001
#
#              futy_Low  futy_Close  futy_Adj_Close  futy_Volume  futy_pctChange
# Date
# 2013-10-24  25.170000   25.240000       19.790556        15500             NaN
# 2013-10-25  25.200001   25.500000       19.994419        14900        0.010301
# 2013-10-28  25.410000   25.480000       19.978731        39500       -0.000785
# 2013-10-29  25.440001   25.530001       20.017941        15600        0.001963
# 2013-10-30  25.360001   25.389999       19.908169       163500       -0.005484
#
# [5 rows x 35 columns]

# %%
# 4. Commodities
commodities_df = pd.read_csv(Path('commodities.csv'), parse_dates=True, index_col='Date')
commodities_df.sort_index(ascending=True, inplace=True)
commodities_df.head()
# Out:
#             Nat Gas Open  Nat Gas High  Nat Gas Low  Nat Gas Close  \
# Date
# 2010-01-04         5.705         5.894        5.705          5.884
# 2010-01-05         5.837         5.858        5.615          5.637
# 2010-01-06         5.690         6.075        5.650          6.009
# 2010-01-07         6.033         6.108        5.763          5.806
# 2010-01-08         5.827         5.853        5.621          5.749
#
#             Nat Gas Adj Close  Nat Gas Volume  Nat Gas pctChange  \
# Date
# 2010-01-04              5.884           78858                NaN
# 2010-01-05              5.637           99492          -0.041978
# 2010-01-06              6.009          140611           0.065993
# 2010-01-07              5.806          135113          -0.033783
# 2010-01-08              5.749          101153          -0.009817
#
#             Crude Oil Open  Crude Oil High  Crude Oil Low  ...  \
# Date                                                       ...
# 2010-01-04       79.629997       81.680000      79.629997  ...
# 2010-01-05       81.629997       82.000000      80.949997  ...
# 2010-01-06       81.430000       83.519997      80.849998  ...
# 2010-01-07       83.199997       83.360001      82.260002  ...
# 2010-01-08       82.650002       83.470001      81.800003  ...
#
#             Corn Fut Adj Close  Corn Fut Volume  Corn Fut pctChange  \
# Date
# 2010-01-04              418.50         140553.0                 NaN
# 2010-01-05              418.75          80967.0            0.000597
# 2010-01-06              421.75          96453.0            0.007164
# 2010-01-07              417.50         137395.0           -0.010077
# 2010-01-08              423.00         137395.0            0.013174
#
#             SB Fut Open  SB Fut High  SB Fut Low  SB Fut Close  \
# Date
# 2010-01-04      1043.00      1065.50     1041.25       1049.50
# 2010-01-05      1047.00      1056.00     1042.00       1052.25
# 2010-01-06      1050.00      1058.50     1042.75       1050.50
# 2010-01-07      1050.50      1052.00     1016.50       1017.75
# 2010-01-08      1018.25      1018.25     1005.00       1013.00
#
#             SB Fut Adj Close  SB Fut Volume  SB Fut pctChange
# Date
# 2010-01-04           1049.50          25947               NaN
# 2010-01-05           1052.25          21073          0.002620
# 2010-01-06           1050.50          17567         -0.001663
# 2010-01-07           1017.75          11750         -0.031176
# 2010-01-08           1013.00          11750         -0.004667
#
# [5 rows x 28 columns]

# %%
# Define all the different data frames into a list
combined_frames = [weather_df,
              crypto_df,
              stock_energy_df,
              commodities_df]

# Concatenate all the dataframes into one
combined_df = pd.concat(combined_frames, axis=1, join='inner', ignore_index=False)
combined_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-24       -8.5  1.023678e+06                    -0.056652
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-24               5375.0                -0.027149
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-24                111582                               0.042199
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
#
#             BTC Transactions  BTC Daily Transactions Change (%)  icln_Open  \
# 2013-10-24             63419                           0.151126      10.99
# 2013-10-25             57236                          -0.097494      10.84
# 2013-10-28             50929                           0.170459      10.75
# 2013-10-29             49770                          -0.022757      10.58
# 2013-10-30             48251                          -0.030520      10.65
#
#             ...  Corn Fut Adj Close  Corn Fut Volume  Corn Fut pctChange  \
# 2013-10-24  ...              440.25         145523.0           -0.005647
# 2013-10-25  ...              440.00         114537.0           -0.000568
# 2013-10-28  ...              430.75         197956.0           -0.021023
# 2013-10-29  ...              432.00         160427.0            0.002902
# 2013-10-30  ...              430.25         145107.0           -0.004051
#
#             SB Fut Open  SB Fut High  SB Fut Low  SB Fut Close  \
# 2013-10-24       1309.0      1318.00     1306.00       1309.75
# 2013-10-25       1309.0      1312.75     1299.25       1300.00
# 2013-10-28       1300.0      1301.25     1270.25       1271.25
# 2013-10-29       1270.0      1280.50     1268.00       1279.00
# 2013-10-30       1279.0      1292.50     1279.00       1287.50
#
#             SB Fut Adj Close  SB Fut Volume  SB Fut pctChange
# 2013-10-24           1309.75         111457         -0.000191
# 2013-10-25           1300.00         104191         -0.007444
# 2013-10-28           1271.25         124280         -0.022115
# 2013-10-29           1279.00          95488          0.006096
# 2013-10-30           1287.50          72297          0.006646
#
# [5 rows x 72 columns]

# %%
# combined_df.info()

# %%
# Copy combined df to create ALL potential features dataset
potential_feature_df = combined_df.copy()
potential_feature_df.drop(
                                    [
                                    'icln_Open',
                                    'icln_High',
                                    'icln_Low',
                                    'xlu_Open',
                                    'xlu_High',
                                    'xlu_Low',
                                    'vpu_Open',
                                    'vpu_High',
                                    'vpu_Low',
                                    'ryu_Open',
                                    'ryu_High',
                                    'ryu_Low',
                                    'futy_Open',
                                    'futy_High',
                                    'futy_Low',
                                    'Corn Fut Open',
                                    'Corn Fut High',
                                    'Corn Fut Low',
                                    'SB Fut Open',
                                    'SB Fut High',
                                    'SB Fut Low',
                                   ],
                                axis=1, inplace=True)

potential_feature_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-24       -8.5  1.023678e+06                    -0.056652
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-24               5375.0                -0.027149
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-24                111582                               0.042199
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
#
#             BTC Transactions  BTC Daily Transactions Change (%)  icln_Close  \
# 2013-10-24             63419                           0.151126       10.90
# 2013-10-25             57236                          -0.097494       10.73
# 2013-10-28             50929                           0.170459       10.62
# 2013-10-29             49770                          -0.022757       10.70
# 2013-10-30             48251                          -0.030520       10.62
#
#             ...  Crude Oil Volume  Crude Oil pctChange  Corn Fut Close  \
# 2013-10-24  ...            248742             0.002581          440.25
# 2013-10-25  ...            192632             0.007620          440.00
# 2013-10-28  ...            230155             0.008482          430.75
# 2013-10-29  ...            183243            -0.004864          432.00
# 2013-10-30  ...            268138            -0.014562          430.25
#
#             Corn Fut Adj Close  Corn Fut Volume  Corn Fut pctChange  \
# 2013-10-24              440.25         145523.0           -0.005647
# 2013-10-25              440.00         114537.0           -0.000568
# 2013-10-28              430.75         197956.0           -0.021023
# 2013-10-29              432.00         160427.0            0.002902
# 2013-10-30              430.25         145107.0           -0.004051
#
#             SB Fut Close  SB Fut Adj Close  SB Fut Volume  SB Fut pctChange
# 2013-10-24       1309.75           1309.75         111457         -0.000191
# 2013-10-25       1300.00           1300.00         104191         -0.007444
# 2013-10-28       1271.25           1271.25         124280         -0.022115
# 2013-10-29       1279.00           1279.00          95488          0.006096
# 2013-10-30       1287.50           1287.50          72297          0.006646
#
# [5 rows x 51 columns]

# %%
# Copy combined df to create ALL potential features dataset
ml_df = potential_feature_df.copy()
ml_df.drop(
                                    [
                                    'icln_Close',
                                    'icln_Volume',
                                    'xlu_Close',
                                    'xlu_Volume',
                                    'vpu_Close',
                                    'vpu_Volume',
                                    'ryu_Close',
                                    'ryu_Volume',
                                    'futy_Close',
                                    'futy_Volume',
                                    'Nat Gas Open',
                                    'Nat Gas Close',
                                    'Nat Gas Volume',
                                    'Crude Oil Open',
                                    'Crude Oil Close',
                                    'Crude Oil Volume',
                                    'Corn Fut Close',
                                    'Corn Fut Adj Close',
                                    'Corn Fut Volume',
                                    'Corn Fut pctChange',
                                    'SB Fut Close',
                                    'SB Fut Adj Close',
                                    'SB Fut Volume',
                                    'SB Fut pctChange'
                                   ],
                                axis=1, inplace=True)

ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-24       -8.5  1.023678e+06                    -0.056652
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-24               5375.0                -0.027149
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-24                111582                               0.042199
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-24             63419                           0.151126
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-24        9.143383  ...       19.790556             NaN         3.645
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-24        3.545              3.629           0.002763       97.690002
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-24      95.949997            97.110001             0.002581
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
#
# [5 rows x 27 columns]

# %%
# Check for no null values
ml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1831 entries, 2013-10-24 to 2021-02-26
# Data columns (total 27 columns):
# temp_diff                                1831 non-null float64
# BTC Volume                               1831 non-null float64
# BTC Daily Volume Change (%)              1831 non-null float64
# BTC New Coins Mined                      1831 non-null float64
# BTC New Coins Mined (%)                  1831 non-null float64
# BTC Active Addresses                     1831 non-null int64
# BTC Daily Active Addresses Change (%)    1831 non-null float64
# BTC Transactions                         1831 non-null int64
# BTC Daily Transactions Change (%)        1831 non-null float64
# icln_Adj_Close                           1831 non-null float64
# icln_pctChange                           1831 non-null float64
# xlu_Adj_Close                            1831 non-null float64
# xlu_pctChange                            1831 non-null float64
# vpu_Adj_Close                            1831 non-null float64
# vpu_pctChange                            1831 non-null float64
# ryu_Adj_Close                            1831 non-null float64
# ryu_pctChange                            1831 non-null float64
# futy_Adj_Close                           1831 non-null float64
# futy_pctChange                           1830 non-null float64
# Nat Gas High                             1831 non-null float64
# Nat Gas Low                              1831 non-null float64
# Nat Gas Adj Close                        1831 non-null float64
# Nat Gas pctChange                        1831 non-null float64
# Crude Oil High                           1831 non-null float64
# Crude Oil Low                            1831 non-null float64
# Crude Oil Adj Close                      1831 non-null float64
# Crude Oil pctChange                      1831 non-null float64
# dtypes: float64(25), int64(2)
# memory usage: 400.5 KB

# %%
ml_df.dropna(axis=0, inplace=True)
ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
# 2013-10-31        8.883341  ...       19.829756       -0.003939         3.659
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
# 2013-10-31        3.560              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
# [5 rows x 27 columns]

# %% [markdown]
# ### ryu One day rolling window

# %%
# Adding predict column looking out 1 day
ml_df['ryu_pred'] = ml_df.ryu_Adj_Close.shift(-1)
ml_df = ml_df.dropna()
ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_pctChange  Nat Gas High  Nat Gas Low  \
# 2013-10-25        9.000779  ...        0.010301         3.731        3.593
# 2013-10-28        8.908505  ...       -0.000785         3.681        3.557
# 2013-10-29        8.975615  ...        0.001963         3.589        3.480
# 2013-10-30        8.908505  ...       -0.005484         3.662        3.610
# 2013-10-31        8.883341  ...       -0.003939         3.659        3.560
#
#             Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25              3.707           0.021494       98.059998
# 2013-10-28              3.569          -0.037227       98.820000
# 2013-10-29              3.497          -0.020174       98.570000
# 2013-10-30              3.620           0.035173       97.820000
# 2013-10-31              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange   ryu_pred
# 2013-10-25      96.989998            97.849998             0.007620  51.402939
# 2013-10-28      97.370003            98.680000             0.008482  51.505379
# 2013-10-29      97.690002            98.199997            -0.004864  51.166584
# 2013-10-30      96.550003            96.769997            -0.014562  50.938068
# 2013-10-31      96.029999            96.379997            -0.004030  51.174458
#
# [5 rows x 28 columns]

# %%
# Random Forest classification to check for feature importance

# Initial Random Forest Imports
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline
import pydotplus
from IPython.display import Image

# %%
# Define Features for xle dataset
X = ml_df.copy()
X.drop('ryu_pred', axis=1, inplace=True)
X.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
# 2013-10-31        8.883341  ...       19.829756       -0.003939         3.659
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
# 2013-10-31        3.560              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
# [5 rows x 27 columns]

# %%
len(X)
# Out:
# 1829

# %%
y = ml_df['ryu_pred']

# %%
len(y)
# Out:
# 1829

# %%
# Splitting into Train and Test sets
split = int(0.7 * len(X))

X_train = X[: split]
X_test = X[split:]

y_train = y[: split]
y_test = y[split:]

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# Scaling data
X_train = X_scaler.transform(X_train)
X_test = X_scaler.transform(X_test)

# %%
len(X_test)
# Out:
# 549

# %%
len(y_test)
# Out:
# 549

# %%
#define model (try to n_features function for automation of df drop)
model = LinearRegression()
#fit model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: 0.03759
# Feature: 1, Score: 0.04113
# Feature: 2, Score: -0.02877
# Feature: 3, Score: 0.04083
# Feature: 4, Score: -0.00886
# Feature: 5, Score: 0.00701
# Feature: 6, Score: -0.02677
# Feature: 7, Score: -0.04808
# Feature: 8, Score: 0.01755
# Feature: 9, Score: -0.03621
# Feature: 10, Score: 0.03475
# Feature: 11, Score: -1.99307
# Feature: 12, Score: 0.23419
# Feature: 13, Score: 2.43630
# Feature: 14, Score: -0.05449
# Feature: 15, Score: 9.36872
# Feature: 16, Score: -0.25401
# Feature: 17, Score: -0.35365
# Feature: 18, Score: 0.05499
# Feature: 19, Score: -0.10088
# Feature: 20, Score: -0.04865
# Feature: 21, Score: 0.19472
# Feature: 22, Score: -0.00973
# Feature: 23, Score: 0.32837
# Feature: 24, Score: 0.50180
# Feature: 25, Score: -0.95849
# Feature: 26, Score: 0.00889

# %%
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

# %%
importances = importance

# %%
#sorting importances
sorted(zip(importances, X.columns), reverse=True)
# Out:
# [(9.368716089050222, 'ryu_Adj_Close'),
#  (2.436303906230192, 'vpu_Adj_Close'),
#  (0.5017981392394975, 'Crude Oil Low'),
#  (0.3283650974378118, 'Crude Oil High'),
#  (0.23419267972194582, 'xlu_pctChange'),
#  (0.19472318590415907, 'Nat Gas Adj Close'),
#  (0.05499432921037263, 'futy_pctChange'),
#  (0.04112624576110547, 'BTC Volume'),
#  (0.04083112521068818, 'BTC New Coins Mined'),
#  (0.03758642448336636, 'temp_diff'),
#  (0.03474926053417228, 'icln_pctChange'),
#  (0.017554153766276247, 'BTC Daily Transactions Change (%)'),
#  (0.008893876723538922, 'Crude Oil pctChange'),
#  (0.007013311998933291, 'BTC Active Addresses'),
#  (-0.008860203383591602, 'BTC New Coins Mined (%)'),
#  (-0.009731745036392195, 'Nat Gas pctChange'),
#  (-0.02677495041342057, 'BTC Daily Active Addresses Change (%)'),
#  (-0.02877051992795526, 'BTC Daily Volume Change (%)'),
#  (-0.036210908937196445, 'icln_Adj_Close'),
#  (-0.048077112879767236, 'BTC Transactions'),
#  (-0.04864966649249488, 'Nat Gas Low'),
#  (-0.05449455549615405, 'vpu_pctChange'),
#  (-0.10087540202294623, 'Nat Gas High'),
#  (-0.25400841082937536, 'ryu_pctChange'),
#  (-0.35364909828263663, 'futy_Adj_Close'),
#  (-0.9584899192152553, 'Crude Oil Adj Close'),
#  (-1.993065154574961, 'xlu_Adj_Close')]

# %%
importances_df =pd.DataFrame(sorted(zip(importances, X.columns), reverse=True))
importances_df
# Out:
#            0                                      1
# 0   9.368716                          ryu_Adj_Close
# 1   2.436304                          vpu_Adj_Close
# 2   0.501798                          Crude Oil Low
# 3   0.328365                         Crude Oil High
# 4   0.234193                          xlu_pctChange
# 5   0.194723                      Nat Gas Adj Close
# 6   0.054994                         futy_pctChange
# 7   0.041126                             BTC Volume
# 8   0.040831                    BTC New Coins Mined
# 9   0.037586                              temp_diff
# 10  0.034749                         icln_pctChange
# 11  0.017554      BTC Daily Transactions Change (%)
# 12  0.008894                    Crude Oil pctChange
# 13  0.007013                   BTC Active Addresses
# 14 -0.008860                BTC New Coins Mined (%)
# 15 -0.009732                      Nat Gas pctChange
# 16 -0.026775  BTC Daily Active Addresses Change (%)
# 17 -0.028771            BTC Daily Volume Change (%)
# 18 -0.036211                         icln_Adj_Close
# 19 -0.048077                       BTC Transactions
# 20 -0.048650                            Nat Gas Low
# 21 -0.054495                          vpu_pctChange
# 22 -0.100875                           Nat Gas High
# 23 -0.254008                          ryu_pctChange
# 24 -0.353649                         futy_Adj_Close
# 25 -0.958490                    Crude Oil Adj Close
# 26 -1.993065                          xlu_Adj_Close

# %%
# Visualize the features by importance
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)

# %%
# Making predictions using the testing data
predictions = model.predict(X_test)
predictions
# Out:
# array([ 88.43832116,  89.07459919,  88.90973644,  85.9973231 ,
#         85.46771475,  85.17257318,  85.20590232,  85.02840974,
#         82.33283816,  82.93801339,  83.19480511,  83.36254391,
#         81.7553052 ,  81.82704963,  83.18141454,  82.39936877,
#         83.30579948,  82.82857429,  83.98788677,  83.84860021,
#         81.61747938,  82.21297737,  82.64106876,  83.06191201,
#         83.03684908,  83.06443484,  83.97469874,  84.55756112,
#         83.51586984,  82.98144585,  83.29780146,  83.82532438,
#         85.58697047,  85.2380279 ,  85.22500368,  85.50868104,
#         85.30831734,  86.41490339,  86.89401627,  86.57798356,
#         86.97590351,  86.90412754,  86.83397424,  87.06487001,
#         87.41480363,  87.78818596,  88.53197861,  88.95580638,
#         88.35150941,  88.20995249,  88.34343358,  88.6565969 ,
#         88.80783466,  88.97017754,  88.9282806 ,  88.85193409,
#         89.06077865,  89.39415002,  90.18371683,  90.90571062,
#         91.07208543,  90.94979223,  91.39815662,  90.88494307,
#         90.04418687,  90.28041389,  91.31716574,  91.8349843 ,
#         91.93943454,  92.63380155,  91.89267073,  90.95539561,
#         91.41418665,  90.53573116,  90.55049438,  90.64628846,
#         90.27021248,  90.94174908,  90.29901199,  90.49223104,
#         98.05601929,  99.74077357,  98.37487854,  99.38073323,
#         98.69797379, 100.73317921, 102.64792822, 102.89307826,
#        100.7805131 , 101.96562353, 103.14781464, 101.40572463,
#         99.17596124,  98.16359063,  98.0674562 ,  98.32861399,
#         99.60864216,  99.72963751,  97.19417485,  97.82103634,
#         98.38717976,  97.39749256,  96.93952799,  97.43897794,
#         97.1009604 ,  96.85895085,  96.39446443,  96.34782258,
#         95.74503885,  97.64160875,  96.37971989,  96.85350217,
#         95.97430429,  94.5651622 ,  94.37665446,  94.27784449,
#         95.42907448,  95.32781288,  95.87944246,  97.31390663,
#         95.25467039,  95.19734986,  97.28897816,  95.49646285,
#         95.66382198,  94.94889984,  94.85976378,  96.62226389,
#         96.09216026,  97.17539351,  97.00375393,  97.24307702,
#         96.53592076,  96.52354448,  97.80730069,  96.87347982,
#         94.7256865 ,  96.17970104,  95.62743262,  96.25117274,
#         96.73851144,  96.53420634,  97.18995388,  97.82947507,
#         96.96629651,  97.12012746,  97.61853516,  97.15584971,
#         96.58658261,  96.05654226,  96.13451172,  96.64785009,
#         95.80785924,  93.84577113,  94.92983956,  94.27152071,
#         93.00663237])

# %%
Results = y_test
Out_of_sample_results = pd.DataFrame({"Actual_Results": y_test,
                   "Predicted Returns": predictions})

# %%
Out_of_sample_results.plot()

# %%
Out_of_sample_results.head()
# Out:
#             Actual_Results  Predicted Returns
# 2018-12-12       89.060501          88.438321
# 2018-12-13       88.696999          89.074599
# 2018-12-14       85.900726          88.909736
# 2018-12-17       85.285568          85.997323
# 2018-12-18       85.043221          85.467715

# %%
#out of sample performance
out_of_sample_mse = mean_squared_error(
    Out_of_sample_results["Actual_Results"],
    Out_of_sample_results["Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

out_of_sample_rmse = np.sqrt(out_of_sample_mse)
r2 = r2_score(Out_of_sample_results["Actual_Results"], Out_of_sample_results["Predicted Returns"])

print(f"Out-of-sample Root Mean Squared Error (RMSE): {out_of_sample_rmse}")
print(f"Out-of-Sample r2: {r2}")
# Out:
# Out-of-sample Root Mean Squared Error (RMSE): 1.694372103512028
# Out-of-Sample r2: 0.9266347177317145

# %%
Out_of_sample_results.plot()

# %%
#In sample performance

in_sample_results = y_train

# Add a column of "in-sample" predictions to that dataframe:  
# YOUR CODE HERE!

in_sample_results = pd.DataFrame({"Actual_Results": y_train})

in_sample_results["in-sample predictions"] = model.predict(X_train)


# Calculate in-sample mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_mse = mean_squared_error(
    in_sample_results["Actual_Results"],
    in_sample_results["in-sample predictions"]
)

# Calculate in-sample root mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_rmse = np.sqrt(in_sample_mse)
r2_in = r2_score(in_sample_results["Actual_Results"], in_sample_results["in-sample predictions"])
print(f"In Sample Root Mean Squared Error (RMSE): {in_sample_rmse}")
print(f"In sample r2: {r2_in}")
# Out:
# In Sample Root Mean Squared Error (RMSE): 0.5682842759260212
# In sample r2: 0.996402296211932

# %%
in_sample_results.plot()

# %%
#AutoRegressor library components
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std

# %%
#Recursive Feature Elimination logic
rfe = RFE(estimator=DecisionTreeRegressor(), n_features_to_select=5)
pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# %%
#Evaluate Model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')

# %%
#RFE performance. MAE = Mean Absolute Error
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MAE: -0.441 (0.040)

# %%
#re-running model with recursive feature elimination prediction
pipeline.fit(X_train, y_train)
yhat = pipeline.predict(X_test)

# %%
oos_pipeline_results = pd.DataFrame({"Actual_Results": y_test,
                   "Pipeline Predicted Returns": yhat})

# %%
oos_pipeline_results.head()
# Out:
#             Actual_Results  Pipeline Predicted Returns
# 2018-12-12       89.060501                   88.280881
# 2018-12-13       88.696999                   89.039780
# 2018-12-14       85.900726                   88.679010
# 2018-12-17       85.285568                   85.915854
# 2018-12-18       85.043221                   85.299193

# %%
#out of sample PIPELINE  performance
oos_pipeline_mse = mean_squared_error(
    oos_pipeline_results["Actual_Results"],
    oos_pipeline_results["Pipeline Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

oos_pipeline_mse = np.sqrt(oos_pipeline_mse)
r2 = r2_score(oos_pipeline_results["Actual_Results"], oos_pipeline_results["Pipeline Predicted Returns"])

print(f"Out-of-sample Pipeline Root Mean Squared Error (RMSE): {oos_pipeline_mse}")
print(f"Out-of-Sample Pipeline r2: {r2}")
# Out:
# Out-of-sample Pipeline Root Mean Squared Error (RMSE): 1.7214512791151395
# Out-of-Sample Pipeline r2: 0.9242709551501165

# %%
oos_pipeline_results.plot()

# %%
#Which features were selected
for i in range(X_train.shape[1]):
	print('Column: %d. Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0. Selected False, Rank: 2.000
# Column: 1. Selected False, Rank: 14.000
# Column: 2. Selected False, Rank: 6.000
# Column: 3. Selected False, Rank: 16.000
# Column: 4. Selected False, Rank: 18.000
# Column: 5. Selected False, Rank: 3.000
# Column: 6. Selected False, Rank: 11.000
# Column: 7. Selected False, Rank: 15.000
# Column: 8. Selected False, Rank: 12.000
# Column: 9. Selected True, Rank: 1.000
# Column: 10. Selected False, Rank: 9.000
# Column: 11. Selected True, Rank: 1.000
# Column: 12. Selected False, Rank: 20.000
# Column: 13. Selected False, Rank: 7.000
# Column: 14. Selected False, Rank: 13.000
# Column: 15. Selected True, Rank: 1.000
# Column: 16. Selected False, Rank: 22.000
# Column: 17. Selected True, Rank: 1.000
# Column: 18. Selected False, Rank: 5.000
# Column: 19. Selected False, Rank: 19.000
# Column: 20. Selected True, Rank: 1.000
# Column: 21. Selected False, Rank: 17.000
# Column: 22. Selected False, Rank: 8.000
# Column: 23. Selected False, Rank: 21.000
# Column: 24. Selected False, Rank: 23.000
# Column: 25. Selected False, Rank: 4.000
# Column: 26. Selected False, Rank: 10.000

# %%
X.columns
# Out:
# Index(['temp_diff', 'BTC Volume', 'BTC Daily Volume Change (%)',
#        'BTC New Coins Mined', 'BTC New Coins Mined (%)',
#        'BTC Active Addresses', 'BTC Daily Active Addresses Change (%)',
#        'BTC Transactions', 'BTC Daily Transactions Change (%)',
#        'icln_Adj_Close', 'icln_pctChange', 'xlu_Adj_Close', 'xlu_pctChange',
#        'vpu_Adj_Close', 'vpu_pctChange', 'ryu_Adj_Close', 'ryu_pctChange',
#        'futy_Adj_Close', 'futy_pctChange', 'Nat Gas High', 'Nat Gas Low',
#        'Nat Gas Adj Close', 'Nat Gas pctChange', 'Crude Oil High',
#        'Crude Oil Low', 'Crude Oil Adj Close', 'Crude Oil pctChange'],
#       dtype='object')

# %% [markdown]
# ### Automatic Feature Reducer

# %%
# from sklearn.datasets import make_classification
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
# # from sklearn.feature_selection import RFECV

# %%
# rfe = RFECV(estimator=DecisionTreeRegressor())
# pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# %%
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')

# %% [markdown]
# ### ryu Seven day rolling window

# %%
# Adding predict column looking out 1 day
ml_df = ml_df.drop(columns="ryu_pred")
ml_df['ryu_pred_7day'] = ml_df.ryu_Adj_Close.shift(-7)
ml_df = ml_df.dropna()
ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_pctChange  Nat Gas High  Nat Gas Low  \
# 2013-10-25        9.000779  ...        0.010301         3.731        3.593
# 2013-10-28        8.908505  ...       -0.000785         3.681        3.557
# 2013-10-29        8.975615  ...        0.001963         3.589        3.480
# 2013-10-30        8.908505  ...       -0.005484         3.662        3.610
# 2013-10-31        8.883341  ...       -0.003939         3.659        3.560
#
#             Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25              3.707           0.021494       98.059998
# 2013-10-28              3.569          -0.037227       98.820000
# 2013-10-29              3.497          -0.020174       98.570000
# 2013-10-30              3.620           0.035173       97.820000
# 2013-10-31              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange  \
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
#             ryu_pred_7day
# 2013-10-25      51.032627
# 2013-10-28      51.521137
# 2013-10-29      51.064144
# 2013-10-30      50.678078
# 2013-10-31      50.843525
#
# [5 rows x 28 columns]

# %%
# Random Forest classification to check for feature importance

# Initial Random Forest Imports
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline
import pydotplus
from IPython.display import Image

# %%
# Define Features for xle dataset
X = ml_df.copy()
X.drop('ryu_pred_7day', axis=1, inplace=True)
X.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
# 2013-10-31        8.883341  ...       19.829756       -0.003939         3.659
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
# 2013-10-31        3.560              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
# [5 rows x 27 columns]

# %%
len(X)
# Out:
# 1822

# %%
y = ml_df['ryu_pred_7day']

# %%
len(y)
# Out:
# 1822

# %%
# Splitting into Train and Test sets
split = int(0.7 * len(X))

X_train = X[: split]
X_test = X[split:]

y_train = y[: split]
y_test = y[split:]

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# Scaling data
X_train = X_scaler.transform(X_train)
X_test = X_scaler.transform(X_test)

# %%
len(X_test)
# Out:
# 547

# %%
len(y_test)
# Out:
# 547

# %%
#define model (try to n_features function for automation of df drop)
model = LinearRegression()
#fit model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: 0.07962
# Feature: 1, Score: 0.19635
# Feature: 2, Score: -0.04717
# Feature: 3, Score: 0.12549
# Feature: 4, Score: -0.01792
# Feature: 5, Score: 0.20636
# Feature: 6, Score: -0.03420
# Feature: 7, Score: -0.34137
# Feature: 8, Score: 0.02934
# Feature: 9, Score: -0.29815
# Feature: 10, Score: 0.02682
# Feature: 11, Score: -11.74248
# Feature: 12, Score: 0.43062
# Feature: 13, Score: 11.98644
# Feature: 14, Score: -0.04025
# Feature: 15, Score: 9.89553
# Feature: 16, Score: -0.37448
# Feature: 17, Score: -0.96938
# Feature: 18, Score: -0.07602
# Feature: 19, Score: -0.50843
# Feature: 20, Score: 0.57478
# Feature: 21, Score: 0.15414
# Feature: 22, Score: 0.03981
# Feature: 23, Score: 3.26506
# Feature: 24, Score: 0.87543
# Feature: 25, Score: -4.80059
# Feature: 26, Score: 0.13913

# %%
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

# %%
importances = importance

# %%
#sorting importances
sorted(zip(importances, X.columns), reverse=True)
# Out:
# [(11.986438347984421, 'vpu_Adj_Close'),
#  (9.89553342461615, 'ryu_Adj_Close'),
#  (3.2650587431321996, 'Crude Oil High'),
#  (0.8754339133642082, 'Crude Oil Low'),
#  (0.574779753922055, 'Nat Gas Low'),
#  (0.4306158761741025, 'xlu_pctChange'),
#  (0.20635656866639854, 'BTC Active Addresses'),
#  (0.19634590957565096, 'BTC Volume'),
#  (0.15414498668250434, 'Nat Gas Adj Close'),
#  (0.13913063588176666, 'Crude Oil pctChange'),
#  (0.12548523697769295, 'BTC New Coins Mined'),
#  (0.07962284653123618, 'temp_diff'),
#  (0.03981440920071636, 'Nat Gas pctChange'),
#  (0.029336274556297896, 'BTC Daily Transactions Change (%)'),
#  (0.026824423722858263, 'icln_pctChange'),
#  (-0.017919488931652412, 'BTC New Coins Mined (%)'),
#  (-0.034202440692778634, 'BTC Daily Active Addresses Change (%)'),
#  (-0.04025178322789673, 'vpu_pctChange'),
#  (-0.04716682879581082, 'BTC Daily Volume Change (%)'),
#  (-0.07601766407447808, 'futy_pctChange'),
#  (-0.29814729719731053, 'icln_Adj_Close'),
#  (-0.3413725459596295, 'BTC Transactions'),
#  (-0.37448105434490686, 'ryu_pctChange'),
#  (-0.508430035750031, 'Nat Gas High'),
#  (-0.9693772820801543, 'futy_Adj_Close'),
#  (-4.800587554261167, 'Crude Oil Adj Close'),
#  (-11.742483882694183, 'xlu_Adj_Close')]

# %%
importances_df =pd.DataFrame(sorted(zip(importances, X.columns), reverse=True))
importances_df
# Out:
#             0                                      1
# 0   11.986438                          vpu_Adj_Close
# 1    9.895533                          ryu_Adj_Close
# 2    3.265059                         Crude Oil High
# 3    0.875434                          Crude Oil Low
# 4    0.574780                            Nat Gas Low
# 5    0.430616                          xlu_pctChange
# 6    0.206357                   BTC Active Addresses
# 7    0.196346                             BTC Volume
# 8    0.154145                      Nat Gas Adj Close
# 9    0.139131                    Crude Oil pctChange
# 10   0.125485                    BTC New Coins Mined
# 11   0.079623                              temp_diff
# 12   0.039814                      Nat Gas pctChange
# 13   0.029336      BTC Daily Transactions Change (%)
# 14   0.026824                         icln_pctChange
# 15  -0.017919                BTC New Coins Mined (%)
# 16  -0.034202  BTC Daily Active Addresses Change (%)
# 17  -0.040252                          vpu_pctChange
# 18  -0.047167            BTC Daily Volume Change (%)
# 19  -0.076018                         futy_pctChange
# 20  -0.298147                         icln_Adj_Close
# 21  -0.341373                       BTC Transactions
# 22  -0.374481                          ryu_pctChange
# 23  -0.508430                           Nat Gas High
# 24  -0.969377                         futy_Adj_Close
# 25  -4.800588                    Crude Oil Adj Close
# 26 -11.742484                          xlu_Adj_Close

# %%
# Visualize the features by importance
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)

# %%
# Making predictions using the testing data
predictions = model.predict(X_test)
predictions
# Out:
# array([ 87.99051919,  87.69185148,  88.63192531,  88.90314036,
#         89.25013186,  88.97365768,  89.69991146,  89.3211489 ,
#         86.59537779,  86.27878889,  85.89340491,  85.94245604,
#         86.12591975,  82.68892575,  83.62448818,  83.69652414,
#         83.74996548,  82.55216843,  82.36473108,  83.78104457,
#         82.95057121,  83.59551138,  83.26463051,  83.97795203,
#         84.10203549,  82.26662974,  82.57889847,  82.81033017,
#         83.40761471,  83.46389877,  83.03854033,  84.2833912 ,
#         84.91301612,  83.98409741,  83.14378426,  83.63017691,
#         83.89685716,  85.30857017,  85.27059353,  85.07125293,
#         85.53309223,  85.2518583 ,  86.0678285 ,  86.85503727,
#         86.30418553,  87.20362367,  86.85095699,  86.52495965,
#         87.02500464,  87.02499046,  87.50475663,  88.19621683,
#         88.56522386,  88.03970387,  87.71111735,  87.89384744,
#         88.03634474,  88.30945818,  88.64165352,  88.6234315 ,
#         88.34875553,  88.68376   ,  88.94332804,  89.67225572,
#         90.40618003,  90.55446859,  90.39811339,  90.78333799,
#         90.36635036,  89.63361327,  89.74567128,  90.73582745,
#         91.24573943,  91.29477092,  91.78909449,  91.11008072,
#         90.19613886,  90.76237606,  89.76161214,  89.74138166,
#         89.89909654,  89.38562573,  89.91013032,  89.42606711,
#         89.55858918,  89.21169829,  89.47903657,  90.3077843 ,
#         89.93733784,  89.08847365,  88.65445442,  88.54318214,
#         88.45061317,  89.00353299,  89.3853613 ,  89.74585783,
#         89.7896948 ,  89.13078611,  90.64930115,  89.40859184,
#         89.1873079 ,  89.9104927 ,  89.57645778,  89.73714839,
#         88.4698808 ,  88.2449536 ,  89.88469915,  90.75732325,
#         90.25392176,  90.00713953,  90.58506097,  91.04820791,
#         90.04988979,  89.57495538,  89.72763353,  89.37027143,
#         89.09156974,  88.48378298,  89.75471939,  88.8658761 ,
#         89.03763295,  87.83928805,  86.65627327,  86.16312985,
#         85.78247283,  86.86102571,  86.82733311,  87.09346373,
#         88.51174162,  86.89871653,  86.73846153,  87.64297846,
#         85.56890956,  85.60702851,  85.26754886,  85.3184484 ,
#         86.69362962,  86.16817793,  87.73372772,  87.14795116,
#         87.44228187,  86.21956851,  85.96933794,  87.35385148,
#         86.38711181,  85.39196786,  86.28949465,  86.14811315,
#         86.94061702,  86.88810136,  86.60768095,  87.36207119,
#         87.84785463,  87.2718594 ,  87.28789404,  87.87007391,
#         87.50190619,  87.26750174,  87.27509329])

# %%
Results = y_test
Out_of_sample_results = pd.DataFrame({"Actual_Results": y_test,
                   "Predicted Returns": predictions})

# %%
Out_of_sample_results.plot()

# %%
Out_of_sample_results.head()
# Out:
#             Actual_Results  Predicted Returns
# 2018-12-04       88.696999          87.990519
# 2018-12-06       85.900726          87.691851
# 2018-12-07       85.285568          88.631925
# 2018-12-10       85.043221          88.903140
# 2018-12-11       85.005936          89.250132

# %%
#out of sample performance
out_of_sample_mse = mean_squared_error(
    Out_of_sample_results["Actual_Results"],
    Out_of_sample_results["Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

out_of_sample_rmse = np.sqrt(out_of_sample_mse)
r2 = r2_score(Out_of_sample_results["Actual_Results"], Out_of_sample_results["Predicted Returns"])

print(f"Out-of-sample Root Mean Squared Error (RMSE): {out_of_sample_rmse}")
print(f"Out-of-Sample r2: {r2}")
# Out:
# Out-of-sample Root Mean Squared Error (RMSE): 5.7863160830434195
# Out-of-Sample r2: 0.1459818770812309

# %%
Out_of_sample_results.plot()

# %%
#In sample performance

in_sample_results = y_train

# Add a column of "in-sample" predictions to that dataframe:  
# YOUR CODE HERE!

in_sample_results = pd.DataFrame({"Actual_Results": y_train})

in_sample_results["in-sample predictions"] = model.predict(X_train)


# Calculate in-sample mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_mse = mean_squared_error(
    in_sample_results["Actual_Results"],
    in_sample_results["in-sample predictions"]
)

# Calculate in-sample root mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_rmse = np.sqrt(in_sample_mse)
r2_in = r2_score(in_sample_results["Actual_Results"], in_sample_results["in-sample predictions"])
print(f"In Sample Root Mean Squared Error (RMSE): {in_sample_rmse}")
print(f"In sample r2: {r2_in}")
# Out:
# In Sample Root Mean Squared Error (RMSE): 1.3338765354285433
# In sample r2: 0.9800319521597411

# %%
in_sample_results.plot()

# %%
#AutoRegressor library components
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std

# %%
#Recursive Feature Elimination logic
rfe = RFE(estimator=DecisionTreeRegressor(), n_features_to_select=5)
pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# %%
#Evaluate Model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')

# %%
#RFE performance. MAE = Mean Absolute Error
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MAE: -1.089 (0.060)

# %%
#re-running model with recursive feature elimination prediction
pipeline.fit(X_train, y_train)
yhat = pipeline.predict(X_test)

# %%
oos_pipeline_results = pd.DataFrame({"Actual_Results": y_test,
                   "Pipeline Predicted Returns": yhat})

# %%
oos_pipeline_results.head()
# Out:
#             Actual_Results  Pipeline Predicted Returns
# 2018-12-04       88.696999                   87.089234
# 2018-12-06       85.900726                   87.038483
# 2018-12-07       85.285568                   87.875256
# 2018-12-10       85.043221                   88.114730
# 2018-12-11       85.005936                   88.410636

# %%
#out of sample PIPELINE  performance
oos_pipeline_mse = mean_squared_error(
    oos_pipeline_results["Actual_Results"],
    oos_pipeline_results["Pipeline Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

oos_pipeline_mse = np.sqrt(oos_pipeline_mse)
r2 = r2_score(oos_pipeline_results["Actual_Results"], oos_pipeline_results["Pipeline Predicted Returns"])

print(f"Out-of-sample Pipeline Root Mean Squared Error (RMSE): {oos_pipeline_mse}")
print(f"Out-of-Sample Pipeline r2: {r2}")
# Out:
# Out-of-sample Pipeline Root Mean Squared Error (RMSE): 4.922322264027409
# Out-of-Sample Pipeline r2: 0.38197952076187447

# %%
oos_pipeline_results.plot()

# %%
#Which features were selected
for i in range(X_train.shape[1]):
	print('Column: %d. Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0. Selected False, Rank: 15.000
# Column: 1. Selected False, Rank: 10.000
# Column: 2. Selected False, Rank: 18.000
# Column: 3. Selected False, Rank: 9.000
# Column: 4. Selected False, Rank: 13.000
# Column: 5. Selected False, Rank: 5.000
# Column: 6. Selected False, Rank: 19.000
# Column: 7. Selected False, Rank: 7.000
# Column: 8. Selected False, Rank: 21.000
# Column: 9. Selected True, Rank: 1.000
# Column: 10. Selected False, Rank: 12.000
# Column: 11. Selected False, Rank: 2.000
# Column: 12. Selected False, Rank: 23.000
# Column: 13. Selected False, Rank: 16.000
# Column: 14. Selected False, Rank: 22.000
# Column: 15. Selected True, Rank: 1.000
# Column: 16. Selected False, Rank: 20.000
# Column: 17. Selected True, Rank: 1.000
# Column: 18. Selected False, Rank: 14.000
# Column: 19. Selected False, Rank: 4.000
# Column: 20. Selected False, Rank: 8.000
# Column: 21. Selected True, Rank: 1.000
# Column: 22. Selected False, Rank: 11.000
# Column: 23. Selected False, Rank: 6.000
# Column: 24. Selected False, Rank: 3.000
# Column: 25. Selected True, Rank: 1.000
# Column: 26. Selected False, Rank: 17.000

# %%
X.columns
# Out:
# Index(['temp_diff', 'BTC Volume', 'BTC Daily Volume Change (%)',
#        'BTC New Coins Mined', 'BTC New Coins Mined (%)',
#        'BTC Active Addresses', 'BTC Daily Active Addresses Change (%)',
#        'BTC Transactions', 'BTC Daily Transactions Change (%)',
#        'icln_Adj_Close', 'icln_pctChange', 'xlu_Adj_Close', 'xlu_pctChange',
#        'vpu_Adj_Close', 'vpu_pctChange', 'ryu_Adj_Close', 'ryu_pctChange',
#        'futy_Adj_Close', 'futy_pctChange', 'Nat Gas High', 'Nat Gas Low',
#        'Nat Gas Adj Close', 'Nat Gas pctChange', 'Crude Oil High',
#        'Crude Oil Low', 'Crude Oil Adj Close', 'Crude Oil pctChange'],
#       dtype='object')
