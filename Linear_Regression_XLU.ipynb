# %%
# Initial imports
import pandas as pd
import seaborn as sns
import numpy as np
from pathlib import Path

# %%
# 1. Weather DataFrame from NYC. 
weather_df = pd.read_csv(Path('weather_nyc_final.csv'), parse_dates=True, index_col='date')
weather_df.sort_index(ascending=True, inplace=True)

weather_df.head()
# Out:
#             temp_diff
# date
# 2010-01-01        3.5
# 2010-01-02       -7.5
# 2010-01-03      -12.0
# 2010-01-04       -6.5
# 2010-01-05       -6.0

# %%
# 2. Crypto DataFrame
crypto_df = pd.read_csv(Path('crypto.csv'), parse_dates=True, index_col='Date')
crypto_df.sort_index(ascending=True, inplace=True)

crypto_df.head()
# Out:
#             BTC Volume  BTC Daily Volume Change (%)  BTC New Coins Mined  \
# Date
# 2009-01-03         0.0                          NaN                  NaN
# 2009-01-04         0.0                          NaN                  0.0
# 2009-01-05         0.0                          NaN                  0.0
# 2009-01-06         0.0                          NaN                  0.0
# 2009-01-07         0.0                          NaN                  0.0
#
#             BTC New Coins Mined (%)  BTC Active Addresses  \
# Date
# 2009-01-03                      NaN                     0
# 2009-01-04                      NaN                     0
# 2009-01-05                      NaN                     0
# 2009-01-06                      NaN                     0
# 2009-01-07                      NaN                     0
#
#             BTC Daily Active Addresses Change (%)  BTC Transactions  \
# Date
# 2009-01-03                                    NaN                 0
# 2009-01-04                                    NaN                 0
# 2009-01-05                                    NaN                 0
# 2009-01-06                                    NaN                 0
# 2009-01-07                                    NaN                 0
#
#             BTC Daily Transactions Change (%)
# Date
# 2009-01-03                                NaN
# 2009-01-04                                NaN
# 2009-01-05                                NaN
# 2009-01-06                                NaN
# 2009-01-07                                NaN

# %%
# 3. Energy Stock Ticker
stock_energy_df = pd.read_csv(Path('stocks_final.csv'), parse_dates=True, index_col='Date')
stock_energy_df.sort_index(ascending=True, inplace=True)
stock_energy_df.head()
# Out:
#             icln_Open  icln_High  icln_Low  icln_Close  icln_Adj_Close  \
# Date
# 2013-10-24      10.99      11.18     10.85       10.90        9.143383
# 2013-10-25      10.84      10.84     10.67       10.73        9.000779
# 2013-10-28      10.75      10.75     10.54       10.62        8.908505
# 2013-10-29      10.58      10.70     10.58       10.70        8.975615
# 2013-10-30      10.65      10.68     10.60       10.62        8.908505
#
#             icln_Volume  icln_pctChange   xlu_Open   xlu_High    xlu_Low  ...  \
# Date                                                                      ...
# 2013-10-24        41600       -0.004566  39.009998  39.009998  38.590000  ...
# 2013-10-25        17200       -0.015596  38.759998  39.230000  38.599998  ...
# 2013-10-28        57200       -0.010252  39.180000  39.349998  38.980000  ...
# 2013-10-29        22900        0.007533  39.110001  39.270000  39.020000  ...
# 2013-10-30        17100       -0.007477  39.240002  39.450001  38.880001  ...
#
#             ryu_Adj_Close  ryu_Volume  ryu_pctChange  futy_Open  futy_High  \
# Date
# 2013-10-24      50.859299        7100      -0.001546  25.250000  25.290001
# 2013-10-25      51.458099        5400       0.011774  25.240000  25.510000
# 2013-10-28      51.402939        2900      -0.001072  25.530001  25.600000
# 2013-10-29      51.505379        5700       0.001993  25.709999  25.709999
# 2013-10-30      51.166584        2800      -0.006578  25.590000  25.690001
#
#              futy_Low  futy_Close  futy_Adj_Close  futy_Volume  futy_pctChange
# Date
# 2013-10-24  25.170000   25.240000       19.790556        15500             NaN
# 2013-10-25  25.200001   25.500000       19.994419        14900        0.010301
# 2013-10-28  25.410000   25.480000       19.978731        39500       -0.000785
# 2013-10-29  25.440001   25.530001       20.017941        15600        0.001963
# 2013-10-30  25.360001   25.389999       19.908169       163500       -0.005484
#
# [5 rows x 35 columns]

# %%
# 4. Commodities
commodities_df = pd.read_csv(Path('commodities.csv'), parse_dates=True, index_col='Date')
commodities_df.sort_index(ascending=True, inplace=True)
commodities_df.head()
# Out:
#             Nat Gas Open  Nat Gas High  Nat Gas Low  Nat Gas Close  \
# Date
# 2010-01-04         5.705         5.894        5.705          5.884
# 2010-01-05         5.837         5.858        5.615          5.637
# 2010-01-06         5.690         6.075        5.650          6.009
# 2010-01-07         6.033         6.108        5.763          5.806
# 2010-01-08         5.827         5.853        5.621          5.749
#
#             Nat Gas Adj Close  Nat Gas Volume  Nat Gas pctChange  \
# Date
# 2010-01-04              5.884           78858                NaN
# 2010-01-05              5.637           99492          -0.041978
# 2010-01-06              6.009          140611           0.065993
# 2010-01-07              5.806          135113          -0.033783
# 2010-01-08              5.749          101153          -0.009817
#
#             Crude Oil Open  Crude Oil High  Crude Oil Low  ...  \
# Date                                                       ...
# 2010-01-04       79.629997       81.680000      79.629997  ...
# 2010-01-05       81.629997       82.000000      80.949997  ...
# 2010-01-06       81.430000       83.519997      80.849998  ...
# 2010-01-07       83.199997       83.360001      82.260002  ...
# 2010-01-08       82.650002       83.470001      81.800003  ...
#
#             Corn Fut Adj Close  Corn Fut Volume  Corn Fut pctChange  \
# Date
# 2010-01-04              418.50         140553.0                 NaN
# 2010-01-05              418.75          80967.0            0.000597
# 2010-01-06              421.75          96453.0            0.007164
# 2010-01-07              417.50         137395.0           -0.010077
# 2010-01-08              423.00         137395.0            0.013174
#
#             SB Fut Open  SB Fut High  SB Fut Low  SB Fut Close  \
# Date
# 2010-01-04      1043.00      1065.50     1041.25       1049.50
# 2010-01-05      1047.00      1056.00     1042.00       1052.25
# 2010-01-06      1050.00      1058.50     1042.75       1050.50
# 2010-01-07      1050.50      1052.00     1016.50       1017.75
# 2010-01-08      1018.25      1018.25     1005.00       1013.00
#
#             SB Fut Adj Close  SB Fut Volume  SB Fut pctChange
# Date
# 2010-01-04           1049.50          25947               NaN
# 2010-01-05           1052.25          21073          0.002620
# 2010-01-06           1050.50          17567         -0.001663
# 2010-01-07           1017.75          11750         -0.031176
# 2010-01-08           1013.00          11750         -0.004667
#
# [5 rows x 28 columns]

# %%
# Define all the different data frames into a list
combined_frames = [weather_df,
              crypto_df,
              stock_energy_df,
              commodities_df]

# Concatenate all the dataframes into one
combined_df = pd.concat(combined_frames, axis=1, join='inner', ignore_index=False)
combined_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-24       -8.5  1.023678e+06                    -0.056652
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-24               5375.0                -0.027149
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-24                111582                               0.042199
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
#
#             BTC Transactions  BTC Daily Transactions Change (%)  icln_Open  \
# 2013-10-24             63419                           0.151126      10.99
# 2013-10-25             57236                          -0.097494      10.84
# 2013-10-28             50929                           0.170459      10.75
# 2013-10-29             49770                          -0.022757      10.58
# 2013-10-30             48251                          -0.030520      10.65
#
#             ...  Corn Fut Adj Close  Corn Fut Volume  Corn Fut pctChange  \
# 2013-10-24  ...              440.25         145523.0           -0.005647
# 2013-10-25  ...              440.00         114537.0           -0.000568
# 2013-10-28  ...              430.75         197956.0           -0.021023
# 2013-10-29  ...              432.00         160427.0            0.002902
# 2013-10-30  ...              430.25         145107.0           -0.004051
#
#             SB Fut Open  SB Fut High  SB Fut Low  SB Fut Close  \
# 2013-10-24       1309.0      1318.00     1306.00       1309.75
# 2013-10-25       1309.0      1312.75     1299.25       1300.00
# 2013-10-28       1300.0      1301.25     1270.25       1271.25
# 2013-10-29       1270.0      1280.50     1268.00       1279.00
# 2013-10-30       1279.0      1292.50     1279.00       1287.50
#
#             SB Fut Adj Close  SB Fut Volume  SB Fut pctChange
# 2013-10-24           1309.75         111457         -0.000191
# 2013-10-25           1300.00         104191         -0.007444
# 2013-10-28           1271.25         124280         -0.022115
# 2013-10-29           1279.00          95488          0.006096
# 2013-10-30           1287.50          72297          0.006646
#
# [5 rows x 72 columns]

# %%
# combined_df.info()

# %%
# Copy combined df to create ALL potential features dataset
potential_feature_df = combined_df.copy()
potential_feature_df.drop(
                                    [
                                    'icln_Open',
                                    'icln_High',
                                    'icln_Low',
                                    'xlu_Open',
                                    'xlu_High',
                                    'xlu_Low',
                                    'vpu_Open',
                                    'vpu_High',
                                    'vpu_Low',
                                    'ryu_Open',
                                    'ryu_High',
                                    'ryu_Low',
                                    'futy_Open',
                                    'futy_High',
                                    'futy_Low',
                                    'Corn Fut Open',
                                    'Corn Fut High',
                                    'Corn Fut Low',
                                    'SB Fut Open',
                                    'SB Fut High',
                                    'SB Fut Low',
                                   ],
                                axis=1, inplace=True)

potential_feature_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-24       -8.5  1.023678e+06                    -0.056652
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-24               5375.0                -0.027149
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-24                111582                               0.042199
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
#
#             BTC Transactions  BTC Daily Transactions Change (%)  icln_Close  \
# 2013-10-24             63419                           0.151126       10.90
# 2013-10-25             57236                          -0.097494       10.73
# 2013-10-28             50929                           0.170459       10.62
# 2013-10-29             49770                          -0.022757       10.70
# 2013-10-30             48251                          -0.030520       10.62
#
#             ...  Crude Oil Volume  Crude Oil pctChange  Corn Fut Close  \
# 2013-10-24  ...            248742             0.002581          440.25
# 2013-10-25  ...            192632             0.007620          440.00
# 2013-10-28  ...            230155             0.008482          430.75
# 2013-10-29  ...            183243            -0.004864          432.00
# 2013-10-30  ...            268138            -0.014562          430.25
#
#             Corn Fut Adj Close  Corn Fut Volume  Corn Fut pctChange  \
# 2013-10-24              440.25         145523.0           -0.005647
# 2013-10-25              440.00         114537.0           -0.000568
# 2013-10-28              430.75         197956.0           -0.021023
# 2013-10-29              432.00         160427.0            0.002902
# 2013-10-30              430.25         145107.0           -0.004051
#
#             SB Fut Close  SB Fut Adj Close  SB Fut Volume  SB Fut pctChange
# 2013-10-24       1309.75           1309.75         111457         -0.000191
# 2013-10-25       1300.00           1300.00         104191         -0.007444
# 2013-10-28       1271.25           1271.25         124280         -0.022115
# 2013-10-29       1279.00           1279.00          95488          0.006096
# 2013-10-30       1287.50           1287.50          72297          0.006646
#
# [5 rows x 51 columns]

# %%
# Copy combined df to create ALL potential features dataset
ml_df = potential_feature_df.copy()
ml_df.drop(
                                    [
                                    'icln_Close',
                                    'icln_Volume',
                                    'xlu_Close',
                                    'xlu_Volume',
                                    'vpu_Close',
                                    'vpu_Volume',
                                    'ryu_Close',
                                    'ryu_Volume',
                                    'futy_Close',
                                    'futy_Volume',
                                    'Nat Gas Open',
                                    'Nat Gas Close',
                                    'Nat Gas Volume',
                                    'Crude Oil Open',
                                    'Crude Oil Close',
                                    'Crude Oil Volume',
                                    'Corn Fut Close',
                                    'Corn Fut Adj Close',
                                    'Corn Fut Volume',
                                    'Corn Fut pctChange',
                                    'SB Fut Close',
                                    'SB Fut Adj Close',
                                    'SB Fut Volume',
                                    'SB Fut pctChange'
                                   ],
                                axis=1, inplace=True)

ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-24       -8.5  1.023678e+06                    -0.056652
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-24               5375.0                -0.027149
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-24                111582                               0.042199
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-24             63419                           0.151126
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-24        9.143383  ...       19.790556             NaN         3.645
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-24        3.545              3.629           0.002763       97.690002
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-24      95.949997            97.110001             0.002581
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
#
# [5 rows x 27 columns]

# %%
# Check for no null values
ml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1831 entries, 2013-10-24 to 2021-02-26
# Data columns (total 27 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   temp_diff                              1831 non-null   float64
#  1   BTC Volume                             1831 non-null   float64
#  2   BTC Daily Volume Change (%)            1831 non-null   float64
#  3   BTC New Coins Mined                    1831 non-null   float64
#  4   BTC New Coins Mined (%)                1831 non-null   float64
#  5   BTC Active Addresses                   1831 non-null   int64
#  6   BTC Daily Active Addresses Change (%)  1831 non-null   float64
#  7   BTC Transactions                       1831 non-null   int64
#  8   BTC Daily Transactions Change (%)      1831 non-null   float64
#  9   icln_Adj_Close                         1831 non-null   float64
#  10  icln_pctChange                         1831 non-null   float64
#  11  xlu_Adj_Close                          1831 non-null   float64
#  12  xlu_pctChange                          1831 non-null   float64
#  13  vpu_Adj_Close                          1831 non-null   float64
#  14  vpu_pctChange                          1831 non-null   float64
#  15  ryu_Adj_Close                          1831 non-null   float64
#  16  ryu_pctChange                          1831 non-null   float64
#  17  futy_Adj_Close                         1831 non-null   float64
#  18  futy_pctChange                         1830 non-null   float64
#  19  Nat Gas High                           1831 non-null   float64
#  20  Nat Gas Low                            1831 non-null   float64
#  21  Nat Gas Adj Close                      1831 non-null   float64
#  22  Nat Gas pctChange                      1831 non-null   float64
#  23  Crude Oil High                         1831 non-null   float64
#  24  Crude Oil Low                          1831 non-null   float64
#  25  Crude Oil Adj Close                    1831 non-null   float64
#  26  Crude Oil pctChange                    1831 non-null   float64
# dtypes: float64(25), int64(2)
# memory usage: 400.5 KB

# %%
ml_df.dropna(axis=0, inplace=True)
ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
# 2013-10-31        8.883341  ...       19.829756       -0.003939         3.659
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
# 2013-10-31        3.560              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
# [5 rows x 27 columns]

# %% [markdown]
# ### XLU One day rolling window

# %%
# Adding predict column looking out 1 day
ml_df['xlu_pred'] = ml_df.xlu_Adj_Close.shift(-1)
ml_df = ml_df.dropna()
ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_pctChange  Nat Gas High  Nat Gas Low  \
# 2013-10-25        9.000779  ...        0.010301         3.731        3.593
# 2013-10-28        8.908505  ...       -0.000785         3.681        3.557
# 2013-10-29        8.975615  ...        0.001963         3.589        3.480
# 2013-10-30        8.908505  ...       -0.005484         3.662        3.610
# 2013-10-31        8.883341  ...       -0.003939         3.659        3.560
#
#             Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25              3.707           0.021494       98.059998
# 2013-10-28              3.569          -0.037227       98.820000
# 2013-10-29              3.497          -0.020174       98.570000
# 2013-10-30              3.620           0.035173       97.820000
# 2013-10-31              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange   xlu_pred
# 2013-10-25      96.989998            97.849998             0.007620  30.058599
# 2013-10-28      97.370003            98.680000             0.008482  30.097013
# 2013-10-29      97.690002            98.199997            -0.004864  29.904930
# 2013-10-30      96.550003            96.769997            -0.014562  29.797352
# 2013-10-31      96.029999            96.379997            -0.004030  30.012503
#
# [5 rows x 28 columns]

# %%
# Random Forest classification to check for feature importance

# Initial Random Forest Imports
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline
import pydotplus
from IPython.display import Image

# %%
# Define Features for xlu dataset
X = ml_df.copy()
X.drop('xlu_pred', axis=1, inplace=True)
X.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
# 2013-10-31        8.883341  ...       19.829756       -0.003939         3.659
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
# 2013-10-31        3.560              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
# [5 rows x 27 columns]

# %%
len(X)
# Out:
# 1829

# %%
y = ml_df['xlu_pred']

# %%
len(y)
# Out:
# 1829

# %%
# Splitting into Train and Test sets
split = int(0.7 * len(X))

X_train = X[: split]
X_test = X[split:]

y_train = y[: split]
y_test = y[split:]

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# Scaling data
X_train = X_scaler.transform(X_train)
X_test = X_scaler.transform(X_test)

# %%
len(X_test)
# Out:
# 549

# %%
len(y_test)
# Out:
# 549

# %%
#define model (try to n_features function for automation of df drop)
model = LinearRegression()
#fit model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: 0.02423
# Feature: 1, Score: 0.02134
# Feature: 2, Score: -0.01300
# Feature: 3, Score: 0.02194
# Feature: 4, Score: -0.00205
# Feature: 5, Score: 0.00283
# Feature: 6, Score: -0.01412
# Feature: 7, Score: -0.02366
# Feature: 8, Score: 0.00078
# Feature: 9, Score: -0.01274
# Feature: 10, Score: 0.00824
# Feature: 11, Score: 4.44751
# Feature: 12, Score: 0.09978
# Feature: 13, Score: 2.13473
# Feature: 14, Score: -0.07613
# Feature: 15, Score: 0.04563
# Feature: 16, Score: -0.06496
# Feature: 17, Score: -0.71486
# Feature: 18, Score: 0.02917
# Feature: 19, Score: -0.09710
# Feature: 20, Score: 0.01756
# Feature: 21, Score: 0.11574
# Feature: 22, Score: -0.00687
# Feature: 23, Score: 0.12678
# Feature: 24, Score: 0.35499
# Feature: 25, Score: -0.59061
# Feature: 26, Score: 0.00069

# %%
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

# %%
importances = importance

# %%
#sorting importances
sorted(zip(importances, X.columns), reverse=True)
# Out:
# [(4.447513577697912, 'xlu_Adj_Close'),
#  (2.1347272353687816, 'vpu_Adj_Close'),
#  (0.35499206823158463, 'Crude Oil Low'),
#  (0.1267808871543317, 'Crude Oil High'),
#  (0.11573965669239215, 'Nat Gas Adj Close'),
#  (0.09977648281677719, 'xlu_pctChange'),
#  (0.04562973768666557, 'ryu_Adj_Close'),
#  (0.02917004629568699, 'futy_pctChange'),
#  (0.024228727457198857, 'temp_diff'),
#  (0.02194027778767015, 'BTC New Coins Mined'),
#  (0.021340917608067306, 'BTC Volume'),
#  (0.017557170500080217, 'Nat Gas Low'),
#  (0.008241717597325799, 'icln_pctChange'),
#  (0.0028277417128381465, 'BTC Active Addresses'),
#  (0.0007755264812298885, 'BTC Daily Transactions Change (%)'),
#  (0.0006920837677445611, 'Crude Oil pctChange'),
#  (-0.0020488147547595968, 'BTC New Coins Mined (%)'),
#  (-0.006872421388258218, 'Nat Gas pctChange'),
#  (-0.012735991766765271, 'icln_Adj_Close'),
#  (-0.013003639638032216, 'BTC Daily Volume Change (%)'),
#  (-0.0141241888471303, 'BTC Daily Active Addresses Change (%)'),
#  (-0.023657327052458314, 'BTC Transactions'),
#  (-0.06496229129218145, 'ryu_pctChange'),
#  (-0.07612902678811378, 'vpu_pctChange'),
#  (-0.09710320620839749, 'Nat Gas High'),
#  (-0.5906120070179125, 'Crude Oil Adj Close'),
#  (-0.7148633532426418, 'futy_Adj_Close')]

# %%
importances_df =pd.DataFrame(sorted(zip(importances, X.columns), reverse=True))
importances_df
# Out:
#            0                                      1
# 0   4.447514                          xlu_Adj_Close
# 1   2.134727                          vpu_Adj_Close
# 2   0.354992                          Crude Oil Low
# 3   0.126781                         Crude Oil High
# 4   0.115740                      Nat Gas Adj Close
# 5   0.099776                          xlu_pctChange
# 6   0.045630                          ryu_Adj_Close
# 7   0.029170                         futy_pctChange
# 8   0.024229                              temp_diff
# 9   0.021940                    BTC New Coins Mined
# 10  0.021341                             BTC Volume
# 11  0.017557                            Nat Gas Low
# 12  0.008242                         icln_pctChange
# 13  0.002828                   BTC Active Addresses
# 14  0.000776      BTC Daily Transactions Change (%)
# 15  0.000692                    Crude Oil pctChange
# 16 -0.002049                BTC New Coins Mined (%)
# 17 -0.006872                      Nat Gas pctChange
# 18 -0.012736                         icln_Adj_Close
# 19 -0.013004            BTC Daily Volume Change (%)
# 20 -0.014124  BTC Daily Active Addresses Change (%)
# 21 -0.023657                       BTC Transactions
# 22 -0.064962                          ryu_pctChange
# 23 -0.076129                          vpu_pctChange
# 24 -0.097103                           Nat Gas High
# 25 -0.590612                    Crude Oil Adj Close
# 26 -0.714863                         futy_Adj_Close

# %%
# Visualize the features by importance
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <AxesSubplot:title={'center':'Features Importances'}, ylabel='1'>

# %%
# Making predictions using the testing data
predictions = model.predict(X_test)
predictions
# Out:
# array([51.71571733, 52.09393711, 52.08602626, 50.37847666, 50.08223889,
#        49.94599248, 49.9781837 , 49.79292094, 48.2489904 , 48.72324336,
#        48.83999612, 48.89217734, 48.01366413, 48.01782434, 48.75632384,
#        48.4185688 , 48.97499034, 48.67740573, 49.23969471, 49.13703955,
#        48.08008207, 48.59609068, 48.78975834, 49.02730113, 49.08643083,
#        49.14570307, 49.6325894 , 49.95748255, 49.26652463, 48.98180565,
#        49.15553123, 49.45662859, 50.43706788, 50.26321431, 50.37283767,
#        50.56787342, 50.47424004, 51.13477826, 51.35980786, 51.19577959,
#        51.42987298, 51.3251052 , 51.24152706, 51.39379012, 51.62286878,
#        51.85986092, 52.28520877, 52.57314057, 52.24156785, 52.1654276 ,
#        52.20437306, 52.51446921, 52.61936877, 52.69096636, 52.6591306 ,
#        52.62325822, 52.81345465, 52.98124997, 53.3392093 , 53.76319707,
#        53.78952516, 53.81621815, 54.03137413, 53.71850346, 53.2182371 ,
#        53.3269765 , 53.86680409, 54.28237348, 54.26066779, 54.67978393,
#        54.29019856, 53.69107394, 53.99248159, 53.52099854, 53.56876959,
#        53.59447023, 53.40836406, 53.79675855, 53.4568258 , 53.59595631,
#        53.44915293, 53.6672295 , 53.98429757, 53.91379563, 53.3168414 ,
#        53.11138203, 53.12141177, 53.01522812, 53.22746015, 53.55032887,
#        53.81095369, 53.87929425, 53.4988657 , 54.39073588, 53.86118088,
#        53.73837735, 54.0002203 , 53.68197852, 53.614103  , 52.89228002,
#        60.29161348, 60.65480119, 60.05868476, 59.79751585, 60.96590472,
#        60.73398032, 61.25884828, 61.11491873, 61.44180502, 61.0945009 ,
#        61.10941854, 62.26933015, 61.6848476 , 60.03026844, 60.78641663,
#        60.40491862, 60.73072958, 61.18945835, 61.03664672, 61.49210031,
#        61.8513652 , 61.36523916, 61.44096003, 61.6993672 , 61.40310519,
#        60.85954334, 60.32374642, 60.28398092, 60.67776961, 59.82648618,
#        58.68554277, 59.15507671, 58.49572597, 58.05793051])

# %%
Results = y_test
Out_of_sample_results = pd.DataFrame({"Actual_Results": y_test,
                   "Predicted Returns": predictions})

# %%
Out_of_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
Out_of_sample_results.head()
# Out:
#             Actual_Results  Predicted Returns
# 2018-12-12       52.045090          51.715717
# 2018-12-13       51.944527          52.093937
# 2018-12-14       50.271549          52.086026
# 2018-12-17       49.933296          50.378477
# 2018-12-18       49.851017          50.082239

# %%
#out of sample performance
out_of_sample_mse = mean_squared_error(
    Out_of_sample_results["Actual_Results"],
    Out_of_sample_results["Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

out_of_sample_rmse = np.sqrt(out_of_sample_mse)
r2 = r2_score(Out_of_sample_results["Actual_Results"], Out_of_sample_results["Predicted Returns"])

print(f"Out-of-sample Root Mean Squared Error (RMSE): {out_of_sample_rmse}")
print(f"Out-of-Sample r2: {r2}")
# Out:
# Out-of-sample Root Mean Squared Error (RMSE): 1.0207383270061077
# Out-of-Sample r2: 0.9423029683332984

# %%
Out_of_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
#In sample performance

in_sample_results = y_train

# Add a column of "in-sample" predictions to that dataframe:  
# YOUR CODE HERE!

in_sample_results = pd.DataFrame({"Actual_Results": y_train})

in_sample_results["in-sample predictions"] = model.predict(X_train)


# Calculate in-sample mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_mse = mean_squared_error(
    in_sample_results["Actual_Results"],
    in_sample_results["in-sample predictions"]
)

# Calculate in-sample root mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_rmse = np.sqrt(in_sample_mse)
r2_in = r2_score(in_sample_results["Actual_Results"], in_sample_results["in-sample predictions"])
print(f"In Sample Root Mean Squared Error (RMSE): {in_sample_rmse}")
print(f"In sample r2: {r2_in}")
# Out:
# In Sample Root Mean Squared Error (RMSE): 0.3542185418763061
# In sample r2: 0.9964375157639976

# %%
in_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
#AutoRegressor library components
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std

# %%
#Recursive Feature Elimination logic
rfe = RFE(estimator=DecisionTreeRegressor(), n_features_to_select=5)
pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# %%
#Evaluate Model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')

# %%
#RFE performance. MAE = Mean Absolute Error
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MAE: -0.274 (0.024)

# %%
#re-running model with recursive feature elimination prediction
pipeline.fit(X_train, y_train)
yhat = pipeline.predict(X_test)

# %%
oos_pipeline_results = pd.DataFrame({"Actual_Results": y_test,
                   "Pipeline Predicted Returns": yhat})

# %%
oos_pipeline_results.head()
# Out:
#             Actual_Results  Pipeline Predicted Returns
# 2018-12-12       52.045090                   51.604618
# 2018-12-13       51.944527                   52.050252
# 2018-12-14       50.271549                   51.950577
# 2018-12-17       49.933296                   50.283878
# 2018-12-18       49.851017                   49.946021

# %%
#out of sample PIPELINE  performance
oos_pipeline_mse = mean_squared_error(
    oos_pipeline_results["Actual_Results"],
    oos_pipeline_results["Pipeline Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

oos_pipeline_mse = np.sqrt(oos_pipeline_mse)
r2 = r2_score(oos_pipeline_results["Actual_Results"], oos_pipeline_results["Pipeline Predicted Returns"])

print(f"Out-of-sample Pipeline Root Mean Squared Error (RMSE): {oos_pipeline_mse}")
print(f"Out-of-Sample Pipeline r2: {r2}")
# Out:
# Out-of-sample Pipeline Root Mean Squared Error (RMSE): 0.9552625995917149
# Out-of-Sample Pipeline r2: 0.9494675708671396

# %%
oos_pipeline_results.plot()
# Out:
# <AxesSubplot:>

# %%
#Which features were selected
for i in range(X_train.shape[1]):
	print('Column: %d. Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0. Selected False, Rank: 8.000
# Column: 1. Selected False, Rank: 9.000
# Column: 2. Selected False, Rank: 4.000
# Column: 3. Selected False, Rank: 10.000
# Column: 4. Selected False, Rank: 21.000
# Column: 5. Selected False, Rank: 14.000
# Column: 6. Selected False, Rank: 5.000
# Column: 7. Selected False, Rank: 19.000
# Column: 8. Selected False, Rank: 18.000
# Column: 9. Selected False, Rank: 2.000
# Column: 10. Selected False, Rank: 13.000
# Column: 11. Selected True, Rank: 1.000
# Column: 12. Selected False, Rank: 23.000
# Column: 13. Selected True, Rank: 1.000
# Column: 14. Selected False, Rank: 22.000
# Column: 15. Selected True, Rank: 1.000
# Column: 16. Selected False, Rank: 3.000
# Column: 17. Selected True, Rank: 1.000
# Column: 18. Selected False, Rank: 16.000
# Column: 19. Selected False, Rank: 15.000
# Column: 20. Selected True, Rank: 1.000
# Column: 21. Selected False, Rank: 17.000
# Column: 22. Selected False, Rank: 7.000
# Column: 23. Selected False, Rank: 6.000
# Column: 24. Selected False, Rank: 20.000
# Column: 25. Selected False, Rank: 11.000
# Column: 26. Selected False, Rank: 12.000

# %%
X.columns
# Out:
# Index(['temp_diff', 'BTC Volume', 'BTC Daily Volume Change (%)',
#        'BTC New Coins Mined', 'BTC New Coins Mined (%)',
#        'BTC Active Addresses', 'BTC Daily Active Addresses Change (%)',
#        'BTC Transactions', 'BTC Daily Transactions Change (%)',
#        'icln_Adj_Close', 'icln_pctChange', 'xlu_Adj_Close', 'xlu_pctChange',
#        'vpu_Adj_Close', 'vpu_pctChange', 'ryu_Adj_Close', 'ryu_pctChange',
#        'futy_Adj_Close', 'futy_pctChange', 'Nat Gas High', 'Nat Gas Low',
#        'Nat Gas Adj Close', 'Nat Gas pctChange', 'Crude Oil High',
#        'Crude Oil Low', 'Crude Oil Adj Close', 'Crude Oil pctChange'],
#       dtype='object')

# %% [markdown]
# ### Automatic Feature Reducer

# %%
# from sklearn.datasets import make_classification
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
# # from sklearn.feature_selection import RFECV

# %%
# rfe = RFECV(estimator=DecisionTreeRegressor())
# pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# %%
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')

# %% [markdown]
# ### XLU Seven day rolling window

# %%
# Adding predict column looking out 1 day
ml_df = ml_df.drop(columns="xlu_pred")
ml_df['xlu_pred_7day'] = ml_df.xlu_Adj_Close.shift(-7)
ml_df = ml_df.dropna()
ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_pctChange  Nat Gas High  Nat Gas Low  \
# 2013-10-25        9.000779  ...        0.010301         3.731        3.593
# 2013-10-28        8.908505  ...       -0.000785         3.681        3.557
# 2013-10-29        8.975615  ...        0.001963         3.589        3.480
# 2013-10-30        8.908505  ...       -0.005484         3.662        3.610
# 2013-10-31        8.883341  ...       -0.003939         3.659        3.560
#
#             Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25              3.707           0.021494       98.059998
# 2013-10-28              3.569          -0.037227       98.820000
# 2013-10-29              3.497          -0.020174       98.570000
# 2013-10-30              3.620           0.035173       97.820000
# 2013-10-31              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange  \
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
#             xlu_pred_7day
# 2013-10-25      29.858826
# 2013-10-28      30.266047
# 2013-10-29      29.981754
# 2013-10-30      29.927975
# 2013-10-31      29.920294
#
# [5 rows x 28 columns]

# %%
# Random Forest classification to check for feature importance

# Initial Random Forest Imports
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline
import pydotplus
from IPython.display import Image

# %%
# Define Features for xle dataset
X = ml_df.copy()
X.drop('xlu_pred_7day', axis=1, inplace=True)
X.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
# 2013-10-31        8.883341  ...       19.829756       -0.003939         3.659
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
# 2013-10-31        3.560              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
# [5 rows x 27 columns]

# %%
len(X)
# Out:
# 1822

# %%
y = ml_df['xlu_pred_7day']

# %%
len(y)
# Out:
# 1822

# %%
# Splitting into Train and Test sets
split = int(0.7 * len(X))

X_train = X[: split]
X_test = X[split:]

y_train = y[: split]
y_test = y[split:]

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# Scaling data
X_train = X_scaler.transform(X_train)
X_test = X_scaler.transform(X_test)

# %%
len(X_test)
# Out:
# 547

# %%
len(y_test)
# Out:
# 547

# %%
#define model (try to n_features function for automation of df drop)
model = LinearRegression()
#fit model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: 0.04741
# Feature: 1, Score: 0.11210
# Feature: 2, Score: -0.02753
# Feature: 3, Score: 0.04524
# Feature: 4, Score: -0.00625
# Feature: 5, Score: 0.17023
# Feature: 6, Score: -0.02675
# Feature: 7, Score: -0.22290
# Feature: 8, Score: 0.02464
# Feature: 9, Score: -0.13404
# Feature: 10, Score: 0.00696
# Feature: 11, Score: -2.57862
# Feature: 12, Score: 0.20875
# Feature: 13, Score: 9.85326
# Feature: 14, Score: -0.08028
# Feature: 15, Score: 0.99576
# Feature: 16, Score: -0.15769
# Feature: 17, Score: -2.59777
# Feature: 18, Score: -0.00262
# Feature: 19, Score: -0.30845
# Feature: 20, Score: 0.55424
# Feature: 21, Score: -0.07119
# Feature: 22, Score: 0.03406
# Feature: 23, Score: 1.37198
# Feature: 24, Score: 1.44040
# Feature: 25, Score: -3.34462
# Feature: 26, Score: 0.08051

# %%
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

# %%
importances = importance

# %%
#sorting importances
sorted(zip(importances, X.columns), reverse=True)
# Out:
# [(9.853259211970277, 'vpu_Adj_Close'),
#  (1.4404011466570918, 'Crude Oil Low'),
#  (1.371981764820624, 'Crude Oil High'),
#  (0.9957550761402711, 'ryu_Adj_Close'),
#  (0.5542433921681028, 'Nat Gas Low'),
#  (0.20875347524048005, 'xlu_pctChange'),
#  (0.1702328329960018, 'BTC Active Addresses'),
#  (0.11210276313110713, 'BTC Volume'),
#  (0.08050676436701976, 'Crude Oil pctChange'),
#  (0.04740900181784709, 'temp_diff'),
#  (0.045241298535659114, 'BTC New Coins Mined'),
#  (0.03406253813361746, 'Nat Gas pctChange'),
#  (0.02463507965632665, 'BTC Daily Transactions Change (%)'),
#  (0.006964909187901354, 'icln_pctChange'),
#  (-0.002621356399778136, 'futy_pctChange'),
#  (-0.006252527911149202, 'BTC New Coins Mined (%)'),
#  (-0.02674667837084822, 'BTC Daily Active Addresses Change (%)'),
#  (-0.027532863668058374, 'BTC Daily Volume Change (%)'),
#  (-0.07119150870644253, 'Nat Gas Adj Close'),
#  (-0.08027750413524637, 'vpu_pctChange'),
#  (-0.13404240230029255, 'icln_Adj_Close'),
#  (-0.1576869186698558, 'ryu_pctChange'),
#  (-0.22290085090955628, 'BTC Transactions'),
#  (-0.30845106733531474, 'Nat Gas High'),
#  (-2.578619633257493, 'xlu_Adj_Close'),
#  (-2.5977663033063187, 'futy_Adj_Close'),
#  (-3.3446183670150287, 'Crude Oil Adj Close')]

# %%
importances_df =pd.DataFrame(sorted(zip(importances, X.columns), reverse=True))
importances_df
# Out:
#            0                                      1
# 0   9.853259                          vpu_Adj_Close
# 1   1.440401                          Crude Oil Low
# 2   1.371982                         Crude Oil High
# 3   0.995755                          ryu_Adj_Close
# 4   0.554243                            Nat Gas Low
# 5   0.208753                          xlu_pctChange
# 6   0.170233                   BTC Active Addresses
# 7   0.112103                             BTC Volume
# 8   0.080507                    Crude Oil pctChange
# 9   0.047409                              temp_diff
# 10  0.045241                    BTC New Coins Mined
# 11  0.034063                      Nat Gas pctChange
# 12  0.024635      BTC Daily Transactions Change (%)
# 13  0.006965                         icln_pctChange
# 14 -0.002621                         futy_pctChange
# 15 -0.006253                BTC New Coins Mined (%)
# 16 -0.026747  BTC Daily Active Addresses Change (%)
# 17 -0.027533            BTC Daily Volume Change (%)
# 18 -0.071192                      Nat Gas Adj Close
# 19 -0.080278                          vpu_pctChange
# 20 -0.134042                         icln_Adj_Close
# 21 -0.157687                          ryu_pctChange
# 22 -0.222901                       BTC Transactions
# 23 -0.308451                           Nat Gas High
# 24 -2.578620                          xlu_Adj_Close
# 25 -2.597766                         futy_Adj_Close
# 26 -3.344618                    Crude Oil Adj Close

# %%
# Visualize the features by importance
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <AxesSubplot:title={'center':'Features Importances'}, ylabel='1'>

# %%
# Making predictions using the testing data
predictions = model.predict(X_test)
predictions
# Out:
# array([51.94440116, 51.74950677, 52.07227184, 52.2480301 , 52.46272512,
#        52.17805132, 52.54683671, 52.41957034, 50.78030486, 50.62001761,
#        50.46522375, 50.55651358, 50.54880421, 48.38609029, 49.19899061,
#        49.18263155, 49.15766282, 48.47253997, 48.39030052, 49.17625253,
#        48.82235564, 49.22440436, 48.91424457, 49.31591118, 49.35579133,
#        48.5724598 , 48.86247805, 48.97228396, 49.34576388, 49.35697498,
#        49.10122647, 49.86615535, 50.23634585, 49.61727646, 49.08490547,
#        49.38655588, 49.52958068, 50.33464822, 50.27350569, 50.25240065,
#        50.60506336, 50.43198593, 50.89807475, 51.36183964, 51.02575987,
#        51.58688555, 51.35729309, 51.07088115, 51.35868085, 51.41595219,
#        51.68180033, 52.12768855, 52.38668624, 52.0453752 , 51.89755942,
#        51.91317211, 52.14608729, 52.29092473, 52.4792118 , 52.49613407,
#        52.34604002, 52.60891739, 52.6944756 , 53.07225462, 53.49406668,
#        53.47945279, 53.50036737, 53.65884589, 53.41846315, 52.99274697,
#        53.00732843, 53.56544336, 53.8919081 , 53.89088987, 54.16231641,
#        53.77899216, 53.21815638, 53.58499972, 52.99574558, 53.03763907,
#        56.66228609, 56.99871743, 57.1897297 , 56.55226693, 56.3312137 ,
#        56.41649292, 56.21136691, 56.26508645, 56.05341652, 56.06128775,
#        55.72447576, 56.53598215, 56.11550053, 56.3615746 , 55.54581261,
#        55.03204245, 54.87351567, 54.42021958, 55.15069537, 55.15836154,
#        55.30398084, 56.1762368 , 55.04025636, 54.87449071, 55.80333376,
#        54.98730181, 55.12892987, 54.74414231, 54.65419893, 55.58555206,
#        55.29511117, 56.03225915, 55.65938897, 56.02250338, 55.40658596,
#        55.2614378 , 56.47186143, 55.83844748, 54.80016542, 55.28692064,
#        55.10959854, 55.58441411, 55.73620035, 55.52200565, 56.02402545,
#        56.31482418, 56.04748797, 55.97214951, 56.27126649, 56.05522208,
#        55.65721379, 55.48752376])

# %%
Results = y_test
Out_of_sample_results = pd.DataFrame({"Actual_Results": y_test,
                   "Predicted Returns": predictions})

# %%
Out_of_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
Out_of_sample_results.head()
# Out:
#             Actual_Results  Predicted Returns
# 2018-12-04       51.944527          51.944401
# 2018-12-06       50.271549          51.749507
# 2018-12-07       49.933296          52.072272
# 2018-12-10       49.851017          52.248030
# 2018-12-11       49.823593          52.462725

# %%
#out of sample performance
out_of_sample_mse = mean_squared_error(
    Out_of_sample_results["Actual_Results"],
    Out_of_sample_results["Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

out_of_sample_rmse = np.sqrt(out_of_sample_mse)
r2 = r2_score(Out_of_sample_results["Actual_Results"], Out_of_sample_results["Predicted Returns"])

print(f"Out-of-sample Root Mean Squared Error (RMSE): {out_of_sample_rmse}")
print(f"Out-of-Sample r2: {r2}")
# Out:
# Out-of-sample Root Mean Squared Error (RMSE): 3.457931718358225
# Out-of-Sample r2: 0.33823745990958576

# %%
Out_of_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
#In sample performance

in_sample_results = y_train

# Add a column of "in-sample" predictions to that dataframe:  
# YOUR CODE HERE!

in_sample_results = pd.DataFrame({"Actual_Results": y_train})

in_sample_results["in-sample predictions"] = model.predict(X_train)


# Calculate in-sample mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_mse = mean_squared_error(
    in_sample_results["Actual_Results"],
    in_sample_results["in-sample predictions"]
)

# Calculate in-sample root mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_rmse = np.sqrt(in_sample_mse)
r2_in = r2_score(in_sample_results["Actual_Results"], in_sample_results["in-sample predictions"])
print(f"In Sample Root Mean Squared Error (RMSE): {in_sample_rmse}")
print(f"In sample r2: {r2_in}")
# Out:
# In Sample Root Mean Squared Error (RMSE): 0.8445505114034594
# In sample r2: 0.9796055670298557

# %%
in_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
#AutoRegressor library components
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std

# %%
#Recursive Feature Elimination logic
rfe = RFE(estimator=DecisionTreeRegressor(), n_features_to_select=5)
pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# %%
#Evaluate Model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')

# %%
#RFE performance. MAE = Mean Absolute Error
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MAE: -0.687 (0.039)

# %%
#re-running model with recursive feature elimination prediction
pipeline.fit(X_train, y_train)
yhat = pipeline.predict(X_test)

# %%
oos_pipeline_results = pd.DataFrame({"Actual_Results": y_test,
                   "Pipeline Predicted Returns": yhat})

# %%
oos_pipeline_results.head()
# Out:
#             Actual_Results  Pipeline Predicted Returns
# 2018-12-04       51.944527                   51.941949
# 2018-12-06       50.271549                   51.957469
# 2018-12-07       49.933296                   52.230455
# 2018-12-10       49.851017                   52.431446
# 2018-12-11       49.823593                   52.538545

# %%
#out of sample PIPELINE  performance
oos_pipeline_mse = mean_squared_error(
    oos_pipeline_results["Actual_Results"],
    oos_pipeline_results["Pipeline Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

oos_pipeline_mse = np.sqrt(oos_pipeline_mse)
r2 = r2_score(oos_pipeline_results["Actual_Results"], oos_pipeline_results["Pipeline Predicted Returns"])

print(f"Out-of-sample Pipeline Root Mean Squared Error (RMSE): {oos_pipeline_mse}")
print(f"Out-of-Sample Pipeline r2: {r2}")
# Out:
# Out-of-sample Pipeline Root Mean Squared Error (RMSE): 2.4653951359040804
# Out-of-Sample Pipeline r2: 0.6636105066334943

# %%
oos_pipeline_results.plot()
# Out:
# <AxesSubplot:>

# %%
#Which features were selected
for i in range(X_train.shape[1]):
	print('Column: %d. Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0. Selected False, Rank: 10.000
# Column: 1. Selected False, Rank: 5.000
# Column: 2. Selected False, Rank: 15.000
# Column: 3. Selected False, Rank: 11.000
# Column: 4. Selected False, Rank: 23.000
# Column: 5. Selected False, Rank: 3.000
# Column: 6. Selected False, Rank: 14.000
# Column: 7. Selected False, Rank: 6.000
# Column: 8. Selected False, Rank: 20.000
# Column: 9. Selected False, Rank: 2.000
# Column: 10. Selected False, Rank: 17.000
# Column: 11. Selected True, Rank: 1.000
# Column: 12. Selected False, Rank: 16.000
# Column: 13. Selected True, Rank: 1.000
# Column: 14. Selected False, Rank: 21.000
# Column: 15. Selected True, Rank: 1.000
# Column: 16. Selected False, Rank: 18.000
# Column: 17. Selected False, Rank: 9.000
# Column: 18. Selected False, Rank: 22.000
# Column: 19. Selected True, Rank: 1.000
# Column: 20. Selected False, Rank: 12.000
# Column: 21. Selected False, Rank: 8.000
# Column: 22. Selected False, Rank: 13.000
# Column: 23. Selected False, Rank: 7.000
# Column: 24. Selected False, Rank: 4.000
# Column: 25. Selected True, Rank: 1.000
# Column: 26. Selected False, Rank: 19.000

# %%
X.columns
# Out:
# Index(['temp_diff', 'BTC Volume', 'BTC Daily Volume Change (%)',
#        'BTC New Coins Mined', 'BTC New Coins Mined (%)',
#        'BTC Active Addresses', 'BTC Daily Active Addresses Change (%)',
#        'BTC Transactions', 'BTC Daily Transactions Change (%)',
#        'icln_Adj_Close', 'icln_pctChange', 'xlu_Adj_Close', 'xlu_pctChange',
#        'vpu_Adj_Close', 'vpu_pctChange', 'ryu_Adj_Close', 'ryu_pctChange',
#        'futy_Adj_Close', 'futy_pctChange', 'Nat Gas High', 'Nat Gas Low',
#        'Nat Gas Adj Close', 'Nat Gas pctChange', 'Crude Oil High',
#        'Crude Oil Low', 'Crude Oil Adj Close', 'Crude Oil pctChange'],
#       dtype='object')
