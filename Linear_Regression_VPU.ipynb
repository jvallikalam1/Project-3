# %%
# Initial imports
import pandas as pd
import seaborn as sns
import numpy as np
from pathlib import Path

# %%
# 1. Weather DataFrame from NYC. 
weather_df = pd.read_csv(Path('weather_nyc_final.csv'), parse_dates=True, index_col='date')
weather_df.sort_index(ascending=True, inplace=True)

weather_df.head()
# Out:
#             temp_diff
# date
# 2010-01-01        3.5
# 2010-01-02       -7.5
# 2010-01-03      -12.0
# 2010-01-04       -6.5
# 2010-01-05       -6.0

# %%
# 2. Crypto DataFrame
crypto_df = pd.read_csv(Path('crypto.csv'), parse_dates=True, index_col='Date')
crypto_df.sort_index(ascending=True, inplace=True)

crypto_df.head()
# Out:
#             BTC Volume  BTC Daily Volume Change (%)  BTC New Coins Mined  \
# Date
# 2009-01-03         0.0                          NaN                  NaN
# 2009-01-04         0.0                          NaN                  0.0
# 2009-01-05         0.0                          NaN                  0.0
# 2009-01-06         0.0                          NaN                  0.0
# 2009-01-07         0.0                          NaN                  0.0
#
#             BTC New Coins Mined (%)  BTC Active Addresses  \
# Date
# 2009-01-03                      NaN                     0
# 2009-01-04                      NaN                     0
# 2009-01-05                      NaN                     0
# 2009-01-06                      NaN                     0
# 2009-01-07                      NaN                     0
#
#             BTC Daily Active Addresses Change (%)  BTC Transactions  \
# Date
# 2009-01-03                                    NaN                 0
# 2009-01-04                                    NaN                 0
# 2009-01-05                                    NaN                 0
# 2009-01-06                                    NaN                 0
# 2009-01-07                                    NaN                 0
#
#             BTC Daily Transactions Change (%)
# Date
# 2009-01-03                                NaN
# 2009-01-04                                NaN
# 2009-01-05                                NaN
# 2009-01-06                                NaN
# 2009-01-07                                NaN

# %%
# 3. Energy Stock Ticker
stock_energy_df = pd.read_csv(Path('stocks_final.csv'), parse_dates=True, index_col='Date')
stock_energy_df.sort_index(ascending=True, inplace=True)
stock_energy_df.head()
# Out:
#             icln_Open  icln_High  icln_Low  icln_Close  icln_Adj_Close  \
# Date
# 2013-10-24      10.99      11.18     10.85       10.90        9.143383
# 2013-10-25      10.84      10.84     10.67       10.73        9.000779
# 2013-10-28      10.75      10.75     10.54       10.62        8.908505
# 2013-10-29      10.58      10.70     10.58       10.70        8.975615
# 2013-10-30      10.65      10.68     10.60       10.62        8.908505
#
#             icln_Volume  icln_pctChange   xlu_Open   xlu_High    xlu_Low  ...  \
# Date                                                                      ...
# 2013-10-24        41600       -0.004566  39.009998  39.009998  38.590000  ...
# 2013-10-25        17200       -0.015596  38.759998  39.230000  38.599998  ...
# 2013-10-28        57200       -0.010252  39.180000  39.349998  38.980000  ...
# 2013-10-29        22900        0.007533  39.110001  39.270000  39.020000  ...
# 2013-10-30        17100       -0.007477  39.240002  39.450001  38.880001  ...
#
#             ryu_Adj_Close  ryu_Volume  ryu_pctChange  futy_Open  futy_High  \
# Date
# 2013-10-24      50.859299        7100      -0.001546  25.250000  25.290001
# 2013-10-25      51.458099        5400       0.011774  25.240000  25.510000
# 2013-10-28      51.402939        2900      -0.001072  25.530001  25.600000
# 2013-10-29      51.505379        5700       0.001993  25.709999  25.709999
# 2013-10-30      51.166584        2800      -0.006578  25.590000  25.690001
#
#              futy_Low  futy_Close  futy_Adj_Close  futy_Volume  futy_pctChange
# Date
# 2013-10-24  25.170000   25.240000       19.790556        15500             NaN
# 2013-10-25  25.200001   25.500000       19.994419        14900        0.010301
# 2013-10-28  25.410000   25.480000       19.978731        39500       -0.000785
# 2013-10-29  25.440001   25.530001       20.017941        15600        0.001963
# 2013-10-30  25.360001   25.389999       19.908169       163500       -0.005484
#
# [5 rows x 35 columns]

# %%
# 4. Commodities
commodities_df = pd.read_csv(Path('commodities.csv'), parse_dates=True, index_col='Date')
commodities_df.sort_index(ascending=True, inplace=True)
commodities_df.head()
# Out:
#             Nat Gas Open  Nat Gas High  Nat Gas Low  Nat Gas Close  \
# Date
# 2010-01-04         5.705         5.894        5.705          5.884
# 2010-01-05         5.837         5.858        5.615          5.637
# 2010-01-06         5.690         6.075        5.650          6.009
# 2010-01-07         6.033         6.108        5.763          5.806
# 2010-01-08         5.827         5.853        5.621          5.749
#
#             Nat Gas Adj Close  Nat Gas Volume  Nat Gas pctChange  \
# Date
# 2010-01-04              5.884           78858                NaN
# 2010-01-05              5.637           99492          -0.041978
# 2010-01-06              6.009          140611           0.065993
# 2010-01-07              5.806          135113          -0.033783
# 2010-01-08              5.749          101153          -0.009817
#
#             Crude Oil Open  Crude Oil High  Crude Oil Low  ...  \
# Date                                                       ...
# 2010-01-04       79.629997       81.680000      79.629997  ...
# 2010-01-05       81.629997       82.000000      80.949997  ...
# 2010-01-06       81.430000       83.519997      80.849998  ...
# 2010-01-07       83.199997       83.360001      82.260002  ...
# 2010-01-08       82.650002       83.470001      81.800003  ...
#
#             Corn Fut Adj Close  Corn Fut Volume  Corn Fut pctChange  \
# Date
# 2010-01-04              418.50         140553.0                 NaN
# 2010-01-05              418.75          80967.0            0.000597
# 2010-01-06              421.75          96453.0            0.007164
# 2010-01-07              417.50         137395.0           -0.010077
# 2010-01-08              423.00         137395.0            0.013174
#
#             SB Fut Open  SB Fut High  SB Fut Low  SB Fut Close  \
# Date
# 2010-01-04      1043.00      1065.50     1041.25       1049.50
# 2010-01-05      1047.00      1056.00     1042.00       1052.25
# 2010-01-06      1050.00      1058.50     1042.75       1050.50
# 2010-01-07      1050.50      1052.00     1016.50       1017.75
# 2010-01-08      1018.25      1018.25     1005.00       1013.00
#
#             SB Fut Adj Close  SB Fut Volume  SB Fut pctChange
# Date
# 2010-01-04           1049.50          25947               NaN
# 2010-01-05           1052.25          21073          0.002620
# 2010-01-06           1050.50          17567         -0.001663
# 2010-01-07           1017.75          11750         -0.031176
# 2010-01-08           1013.00          11750         -0.004667
#
# [5 rows x 28 columns]

# %%
# Define all the different data frames into a list
combined_frames = [weather_df,
              crypto_df,
              stock_energy_df,
              commodities_df]

# Concatenate all the dataframes into one
combined_df = pd.concat(combined_frames, axis=1, join='inner', ignore_index=False)
combined_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-24       -8.5  1.023678e+06                    -0.056652
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-24               5375.0                -0.027149
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-24                111582                               0.042199
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
#
#             BTC Transactions  BTC Daily Transactions Change (%)  icln_Open  \
# 2013-10-24             63419                           0.151126      10.99
# 2013-10-25             57236                          -0.097494      10.84
# 2013-10-28             50929                           0.170459      10.75
# 2013-10-29             49770                          -0.022757      10.58
# 2013-10-30             48251                          -0.030520      10.65
#
#             ...  Corn Fut Adj Close  Corn Fut Volume  Corn Fut pctChange  \
# 2013-10-24  ...              440.25         145523.0           -0.005647
# 2013-10-25  ...              440.00         114537.0           -0.000568
# 2013-10-28  ...              430.75         197956.0           -0.021023
# 2013-10-29  ...              432.00         160427.0            0.002902
# 2013-10-30  ...              430.25         145107.0           -0.004051
#
#             SB Fut Open  SB Fut High  SB Fut Low  SB Fut Close  \
# 2013-10-24       1309.0      1318.00     1306.00       1309.75
# 2013-10-25       1309.0      1312.75     1299.25       1300.00
# 2013-10-28       1300.0      1301.25     1270.25       1271.25
# 2013-10-29       1270.0      1280.50     1268.00       1279.00
# 2013-10-30       1279.0      1292.50     1279.00       1287.50
#
#             SB Fut Adj Close  SB Fut Volume  SB Fut pctChange
# 2013-10-24           1309.75         111457         -0.000191
# 2013-10-25           1300.00         104191         -0.007444
# 2013-10-28           1271.25         124280         -0.022115
# 2013-10-29           1279.00          95488          0.006096
# 2013-10-30           1287.50          72297          0.006646
#
# [5 rows x 72 columns]

# %%
# combined_df.info()

# %%
# Copy combined df to create ALL potential features dataset
potential_feature_df = combined_df.copy()
potential_feature_df.drop(
                                    [
                                    'icln_Open',
                                    'icln_High',
                                    'icln_Low',
                                    'xlu_Open',
                                    'xlu_High',
                                    'xlu_Low',
                                    'vpu_Open',
                                    'vpu_High',
                                    'vpu_Low',
                                    'ryu_Open',
                                    'ryu_High',
                                    'ryu_Low',
                                    'futy_Open',
                                    'futy_High',
                                    'futy_Low',
                                    'Corn Fut Open',
                                    'Corn Fut High',
                                    'Corn Fut Low',
                                    'SB Fut Open',
                                    'SB Fut High',
                                    'SB Fut Low',
                                   ],
                                axis=1, inplace=True)

potential_feature_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-24       -8.5  1.023678e+06                    -0.056652
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-24               5375.0                -0.027149
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-24                111582                               0.042199
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
#
#             BTC Transactions  BTC Daily Transactions Change (%)  icln_Close  \
# 2013-10-24             63419                           0.151126       10.90
# 2013-10-25             57236                          -0.097494       10.73
# 2013-10-28             50929                           0.170459       10.62
# 2013-10-29             49770                          -0.022757       10.70
# 2013-10-30             48251                          -0.030520       10.62
#
#             ...  Crude Oil Volume  Crude Oil pctChange  Corn Fut Close  \
# 2013-10-24  ...            248742             0.002581          440.25
# 2013-10-25  ...            192632             0.007620          440.00
# 2013-10-28  ...            230155             0.008482          430.75
# 2013-10-29  ...            183243            -0.004864          432.00
# 2013-10-30  ...            268138            -0.014562          430.25
#
#             Corn Fut Adj Close  Corn Fut Volume  Corn Fut pctChange  \
# 2013-10-24              440.25         145523.0           -0.005647
# 2013-10-25              440.00         114537.0           -0.000568
# 2013-10-28              430.75         197956.0           -0.021023
# 2013-10-29              432.00         160427.0            0.002902
# 2013-10-30              430.25         145107.0           -0.004051
#
#             SB Fut Close  SB Fut Adj Close  SB Fut Volume  SB Fut pctChange
# 2013-10-24       1309.75           1309.75         111457         -0.000191
# 2013-10-25       1300.00           1300.00         104191         -0.007444
# 2013-10-28       1271.25           1271.25         124280         -0.022115
# 2013-10-29       1279.00           1279.00          95488          0.006096
# 2013-10-30       1287.50           1287.50          72297          0.006646
#
# [5 rows x 51 columns]

# %%
# Copy combined df to create ALL potential features dataset
ml_df = potential_feature_df.copy()
ml_df.drop(
                                    [
                                    'icln_Close',
                                    'icln_Volume',
                                    'xlu_Close',
                                    'xlu_Volume',
                                    'vpu_Close',
                                    'vpu_Volume',
                                    'ryu_Close',
                                    'ryu_Volume',
                                    'futy_Close',
                                    'futy_Volume',
                                    'Nat Gas Open',
                                    'Nat Gas Close',
                                    'Nat Gas Volume',
                                    'Crude Oil Open',
                                    'Crude Oil Close',
                                    'Crude Oil Volume',
                                    'Corn Fut Close',
                                    'Corn Fut Adj Close',
                                    'Corn Fut Volume',
                                    'Corn Fut pctChange',
                                    'SB Fut Close',
                                    'SB Fut Adj Close',
                                    'SB Fut Volume',
                                    'SB Fut pctChange'
                                   ],
                                axis=1, inplace=True)

ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-24       -8.5  1.023678e+06                    -0.056652
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-24               5375.0                -0.027149
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-24                111582                               0.042199
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-24             63419                           0.151126
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-24        9.143383  ...       19.790556             NaN         3.645
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-24        3.545              3.629           0.002763       97.690002
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-24      95.949997            97.110001             0.002581
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
#
# [5 rows x 27 columns]

# %%
# Check for no null values
ml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1831 entries, 2013-10-24 to 2021-02-26
# Data columns (total 27 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   temp_diff                              1831 non-null   float64
#  1   BTC Volume                             1831 non-null   float64
#  2   BTC Daily Volume Change (%)            1831 non-null   float64
#  3   BTC New Coins Mined                    1831 non-null   float64
#  4   BTC New Coins Mined (%)                1831 non-null   float64
#  5   BTC Active Addresses                   1831 non-null   int64
#  6   BTC Daily Active Addresses Change (%)  1831 non-null   float64
#  7   BTC Transactions                       1831 non-null   int64
#  8   BTC Daily Transactions Change (%)      1831 non-null   float64
#  9   icln_Adj_Close                         1831 non-null   float64
#  10  icln_pctChange                         1831 non-null   float64
#  11  xlu_Adj_Close                          1831 non-null   float64
#  12  xlu_pctChange                          1831 non-null   float64
#  13  vpu_Adj_Close                          1831 non-null   float64
#  14  vpu_pctChange                          1831 non-null   float64
#  15  ryu_Adj_Close                          1831 non-null   float64
#  16  ryu_pctChange                          1831 non-null   float64
#  17  futy_Adj_Close                         1831 non-null   float64
#  18  futy_pctChange                         1830 non-null   float64
#  19  Nat Gas High                           1831 non-null   float64
#  20  Nat Gas Low                            1831 non-null   float64
#  21  Nat Gas Adj Close                      1831 non-null   float64
#  22  Nat Gas pctChange                      1831 non-null   float64
#  23  Crude Oil High                         1831 non-null   float64
#  24  Crude Oil Low                          1831 non-null   float64
#  25  Crude Oil Adj Close                    1831 non-null   float64
#  26  Crude Oil pctChange                    1831 non-null   float64
# dtypes: float64(25), int64(2)
# memory usage: 400.5 KB

# %%
ml_df.dropna(axis=0, inplace=True)
ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
# 2013-10-31        8.883341  ...       19.829756       -0.003939         3.659
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
# 2013-10-31        3.560              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
# [5 rows x 27 columns]

# %% [markdown]
# ### VPU One day rolling window

# %%
# Adding predict column looking out 1 day
ml_df['vpu_pred'] = ml_df.vpu_Adj_Close.shift(-1)
ml_df = ml_df.dropna()
ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_pctChange  Nat Gas High  Nat Gas Low  \
# 2013-10-25        9.000779  ...        0.010301         3.731        3.593
# 2013-10-28        8.908505  ...       -0.000785         3.681        3.557
# 2013-10-29        8.975615  ...        0.001963         3.589        3.480
# 2013-10-30        8.908505  ...       -0.005484         3.662        3.610
# 2013-10-31        8.883341  ...       -0.003939         3.659        3.560
#
#             Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25              3.707           0.021494       98.059998
# 2013-10-28              3.569          -0.037227       98.820000
# 2013-10-29              3.497          -0.020174       98.570000
# 2013-10-30              3.620           0.035173       97.820000
# 2013-10-31              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange   vpu_pred
# 2013-10-25      96.989998            97.849998             0.007620  67.065491
# 2013-10-28      97.370003            98.680000             0.008482  67.167412
# 2013-10-29      97.690002            98.199997            -0.004864  66.783188
# 2013-10-30      96.550003            96.769997            -0.014562  66.555786
# 2013-10-31      96.029999            96.379997            -0.004030  66.908669
#
# [5 rows x 28 columns]

# %%
# Random Forest classification to check for feature importance

# Initial Random Forest Imports
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline
import pydotplus
from IPython.display import Image

# %%
# Define Features for vpu dataset
X = ml_df.copy()
X.drop('vpu_pred', axis=1, inplace=True)
X.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
# 2013-10-31        8.883341  ...       19.829756       -0.003939         3.659
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
# 2013-10-31        3.560              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
# [5 rows x 27 columns]

# %%
len(X)
# Out:
# 1829

# %%
y = ml_df['vpu_pred']

# %%
len(y)
# Out:
# 1829

# %%
# Splitting into Train and Test sets
split = int(0.7 * len(X))

X_train = X[: split]
X_test = X[split:]

y_train = y[: split]
y_test = y[split:]

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# Scaling data
X_train = X_scaler.transform(X_train)
X_test = X_scaler.transform(X_test)

# %%
len(X_test)
# Out:
# 549

# %%
len(y_test)
# Out:
# 549

# %%
#define model (try to n_features function for automation of df drop)
model = LinearRegression()
#fit model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: 0.04919
# Feature: 1, Score: 0.05144
# Feature: 2, Score: -0.02982
# Feature: 3, Score: 0.03673
# Feature: 4, Score: -0.00511
# Feature: 5, Score: -0.00320
# Feature: 6, Score: -0.02779
# Feature: 7, Score: -0.04913
# Feature: 8, Score: 0.00268
# Feature: 9, Score: -0.03327
# Feature: 10, Score: 0.02351
# Feature: 11, Score: -2.87961
# Feature: 12, Score: 0.40960
# Feature: 13, Score: 17.61635
# Feature: 14, Score: -0.37124
# Feature: 15, Score: 0.05423
# Feature: 16, Score: -0.14780
# Feature: 17, Score: -1.37982
# Feature: 18, Score: 0.08375
# Feature: 19, Score: -0.14563
# Feature: 20, Score: -0.08997
# Feature: 21, Score: 0.29733
# Feature: 22, Score: -0.01905
# Feature: 23, Score: 0.11007
# Feature: 24, Score: 0.80453
# Feature: 25, Score: -1.11417
# Feature: 26, Score: 0.00126

# %%
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

# %%
importances = importance

# %%
#sorting importances
sorted(zip(importances, X.columns), reverse=True)
# Out:
# [(17.616351947930962, 'vpu_Adj_Close'),
#  (0.8045343905129728, 'Crude Oil Low'),
#  (0.4095978556572273, 'xlu_pctChange'),
#  (0.29732867466923896, 'Nat Gas Adj Close'),
#  (0.11007165216385344, 'Crude Oil High'),
#  (0.08374999851217287, 'futy_pctChange'),
#  (0.0542327375825725, 'ryu_Adj_Close'),
#  (0.051440303839136246, 'BTC Volume'),
#  (0.049187579880592656, 'temp_diff'),
#  (0.03673086978734385, 'BTC New Coins Mined'),
#  (0.02351092369817322, 'icln_pctChange'),
#  (0.0026812420178695673, 'BTC Daily Transactions Change (%)'),
#  (0.0012632395249156975, 'Crude Oil pctChange'),
#  (-0.0031968802149855017, 'BTC Active Addresses'),
#  (-0.0051070469765027385, 'BTC New Coins Mined (%)'),
#  (-0.01904632106134216, 'Nat Gas pctChange'),
#  (-0.02779165664155494, 'BTC Daily Active Addresses Change (%)'),
#  (-0.029817916388935464, 'BTC Daily Volume Change (%)'),
#  (-0.033265623330554946, 'icln_Adj_Close'),
#  (-0.04913150201672711, 'BTC Transactions'),
#  (-0.08997463387501152, 'Nat Gas Low'),
#  (-0.1456331166255763, 'Nat Gas High'),
#  (-0.14779998552594126, 'ryu_pctChange'),
#  (-0.3712384485209388, 'vpu_pctChange'),
#  (-1.1141731421485557, 'Crude Oil Adj Close'),
#  (-1.379821783639078, 'futy_Adj_Close'),
#  (-2.879611892193155, 'xlu_Adj_Close')]

# %%
importances_df =pd.DataFrame(sorted(zip(importances, X.columns), reverse=True))
importances_df
# Out:
#             0                                      1
# 0   17.616352                          vpu_Adj_Close
# 1    0.804534                          Crude Oil Low
# 2    0.409598                          xlu_pctChange
# 3    0.297329                      Nat Gas Adj Close
# 4    0.110072                         Crude Oil High
# 5    0.083750                         futy_pctChange
# 6    0.054233                          ryu_Adj_Close
# 7    0.051440                             BTC Volume
# 8    0.049188                              temp_diff
# 9    0.036731                    BTC New Coins Mined
# 10   0.023511                         icln_pctChange
# 11   0.002681      BTC Daily Transactions Change (%)
# 12   0.001263                    Crude Oil pctChange
# 13  -0.003197                   BTC Active Addresses
# 14  -0.005107                BTC New Coins Mined (%)
# 15  -0.019046                      Nat Gas pctChange
# 16  -0.027792  BTC Daily Active Addresses Change (%)
# 17  -0.029818            BTC Daily Volume Change (%)
# 18  -0.033266                         icln_Adj_Close
# 19  -0.049132                       BTC Transactions
# 20  -0.089975                            Nat Gas Low
# 21  -0.145633                           Nat Gas High
# 22  -0.147800                          ryu_pctChange
# 23  -0.371238                          vpu_pctChange
# 24  -1.114173                    Crude Oil Adj Close
# 25  -1.379822                         futy_Adj_Close
# 26  -2.879612                          xlu_Adj_Close

# %%
# Visualize the features by importance
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <AxesSubplot:title={'center':'Features Importances'}, ylabel='1'>

# %%
# Making predictions using the testing data
predictions = model.predict(X_test)
predictions
# Out:
# array([115.82232188, 116.66359638, 116.59531014, 112.73651413,
#        111.99987224, 111.75581337, 112.01381228, 111.39468931,
#        107.88012661, 108.88970157, 109.07261095, 109.31377186,
#        107.25672458, 107.33110057, 109.07877409, 108.307729  ,
#        109.57666574, 108.86303784, 110.23560804, 109.92937218,
#        107.66917149, 108.92429249, 109.39973108, 110.07692832,
#        110.26226424, 110.29129977, 111.38214953, 112.14425485,
#        110.65791021, 109.99489587, 110.38959568, 110.95234909,
#        113.08542904, 112.72426105, 112.95955963, 113.32516374,
#        112.9343159 , 114.38044745, 115.00242628, 114.61189635,
#        115.02704542, 114.8190166 , 114.65993556, 115.12124543,
#        115.64258657, 116.17076367, 117.11267014, 117.80463309,
#        117.04897282, 116.76991484, 116.90218599, 117.49693913,
#        117.71544492, 118.00623122, 117.83229888, 117.67217961,
#        118.08485918, 118.50949017, 119.38004421, 120.22974984,
#        120.25172295, 120.19018395, 120.7304301 , 120.19921019,
#        132.73822622, 134.20824697, 132.90174079, 133.655985  ,
#        133.62584552, 135.66962355, 136.22579046, 136.02257647,
#        135.76592126, 131.95899089, 131.76105633, 130.92961439,
#        133.75377806, 135.69637175, 133.68267991, 134.91375367,
#        134.62789371, 136.98052172, 139.82822499, 140.55127714,
#        137.9306142 , 139.08169041, 140.5580208 , 137.97159403,
#        135.25386963, 134.00368209, 134.06679329, 134.06025235,
#        135.76197457, 136.30547317, 132.90754331, 133.64003641,
#        134.42068223, 133.1320224 , 132.01305468, 132.67622335,
#        132.27239949, 131.96828067, 131.50094019, 131.62809051,
#        130.93149134, 133.61040186, 132.21802104, 133.09174086,
#        131.51938359, 130.15135883, 130.12478464, 129.77421857,
#        131.41890521, 131.06190472, 131.79598524, 133.68005276,
#        130.67838095, 130.61885396, 134.015002  , 132.51911482,
#        133.17573625, 131.9496156 , 131.58202836, 133.92332639,
#        133.31134578, 134.44089037, 134.09614258, 134.74451574,
#        133.85655932, 133.77729353, 136.09345237, 134.6872499 ,
#        131.30310005, 133.04887587, 132.11373623, 133.03854072,
#        133.97051207, 133.67461346, 134.76929532, 135.55465008,
#        134.67104915, 134.85582297, 135.46419488, 134.95244607,
#        133.75662943, 132.69849381, 132.75292965, 133.44903124,
#        131.8541019 , 129.37268225, 130.28671804, 129.18411666,
#        128.06311113])

# %%
Results = y_test
Out_of_sample_results = pd.DataFrame({"Actual_Results": y_test,
                   "Predicted Returns": predictions})

# %%
Out_of_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
Out_of_sample_results.head()
# Out:
#             Actual_Results  Predicted Returns
# 2018-12-12      116.595085         115.822322
# 2018-12-13      116.298706         116.663596
# 2018-12-14      112.519936         116.595310
# 2018-12-17      111.714188         112.736514
# 2018-12-18      111.575249         111.999872

# %%
#out of sample performance
out_of_sample_mse = mean_squared_error(
    Out_of_sample_results["Actual_Results"],
    Out_of_sample_results["Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

out_of_sample_rmse = np.sqrt(out_of_sample_mse)
r2 = r2_score(Out_of_sample_results["Actual_Results"], Out_of_sample_results["Predicted Returns"])

print(f"Out-of-sample Root Mean Squared Error (RMSE): {out_of_sample_rmse}")
print(f"Out-of-Sample r2: {r2}")
# Out:
# Out-of-sample Root Mean Squared Error (RMSE): 2.245679577471418
# Out-of-Sample r2: 0.935958871582125

# %%
Out_of_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
#In sample performance

in_sample_results = y_train

# Add a column of "in-sample" predictions to that dataframe:  
# YOUR CODE HERE!

in_sample_results = pd.DataFrame({"Actual_Results": y_train})

in_sample_results["in-sample predictions"] = model.predict(X_train)


# Calculate in-sample mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_mse = mean_squared_error(
    in_sample_results["Actual_Results"],
    in_sample_results["in-sample predictions"]
)

# Calculate in-sample root mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_rmse = np.sqrt(in_sample_mse)
r2_in = r2_score(in_sample_results["Actual_Results"], in_sample_results["in-sample predictions"])
print(f"In Sample Root Mean Squared Error (RMSE): {in_sample_rmse}")
print(f"In sample r2: {r2_in}")
# Out:
# In Sample Root Mean Squared Error (RMSE): 0.7625509013263199
# In sample r2: 0.9967883016724531

# %%
in_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
#AutoRegressor library components
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std

# %%
#Recursive Feature Elimination logic
rfe = RFE(estimator=DecisionTreeRegressor(), n_features_to_select=5)
pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# %%
#Evaluate Model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')

# %%
#RFE performance. MAE = Mean Absolute Error
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MAE: -0.590 (0.054)

# %%
#re-running model with recursive feature elimination prediction
pipeline.fit(X_train, y_train)
yhat = pipeline.predict(X_test)

# %%
oos_pipeline_results = pd.DataFrame({"Actual_Results": y_test,
                   "Pipeline Predicted Returns": yhat})

# %%
oos_pipeline_results.head()
# Out:
#             Actual_Results  Pipeline Predicted Returns
# 2018-12-12      116.595085                  115.639912
# 2018-12-13      116.298706                  116.572874
# 2018-12-14      112.519936                  116.299176
# 2018-12-17      111.714188                  112.583688
# 2018-12-18      111.575249                  111.739568

# %%
#out of sample PIPELINE  performance
oos_pipeline_mse = mean_squared_error(
    oos_pipeline_results["Actual_Results"],
    oos_pipeline_results["Pipeline Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

oos_pipeline_mse = np.sqrt(oos_pipeline_mse)
r2 = r2_score(oos_pipeline_results["Actual_Results"], oos_pipeline_results["Pipeline Predicted Returns"])

print(f"Out-of-sample Pipeline Root Mean Squared Error (RMSE): {oos_pipeline_mse}")
print(f"Out-of-Sample Pipeline r2: {r2}")
# Out:
# Out-of-sample Pipeline Root Mean Squared Error (RMSE): 2.105031769925584
# Out-of-Sample Pipeline r2: 0.9437295088010363

# %%
oos_pipeline_results.plot()
# Out:
# <AxesSubplot:>

# %%
#Which features were selected
for i in range(X_train.shape[1]):
	print('Column: %d. Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0. Selected False, Rank: 10.000
# Column: 1. Selected False, Rank: 4.000
# Column: 2. Selected False, Rank: 8.000
# Column: 3. Selected False, Rank: 5.000
# Column: 4. Selected False, Rank: 17.000
# Column: 5. Selected False, Rank: 3.000
# Column: 6. Selected False, Rank: 16.000
# Column: 7. Selected False, Rank: 13.000
# Column: 8. Selected False, Rank: 19.000
# Column: 9. Selected False, Rank: 2.000
# Column: 10. Selected False, Rank: 14.000
# Column: 11. Selected True, Rank: 1.000
# Column: 12. Selected False, Rank: 7.000
# Column: 13. Selected True, Rank: 1.000
# Column: 14. Selected False, Rank: 23.000
# Column: 15. Selected False, Rank: 6.000
# Column: 16. Selected False, Rank: 15.000
# Column: 17. Selected True, Rank: 1.000
# Column: 18. Selected True, Rank: 1.000
# Column: 19. Selected False, Rank: 22.000
# Column: 20. Selected True, Rank: 1.000
# Column: 21. Selected False, Rank: 20.000
# Column: 22. Selected False, Rank: 12.000
# Column: 23. Selected False, Rank: 9.000
# Column: 24. Selected False, Rank: 18.000
# Column: 25. Selected False, Rank: 21.000
# Column: 26. Selected False, Rank: 11.000

# %%
X.columns
# Out:
# Index(['temp_diff', 'BTC Volume', 'BTC Daily Volume Change (%)',
#        'BTC New Coins Mined', 'BTC New Coins Mined (%)',
#        'BTC Active Addresses', 'BTC Daily Active Addresses Change (%)',
#        'BTC Transactions', 'BTC Daily Transactions Change (%)',
#        'icln_Adj_Close', 'icln_pctChange', 'xlu_Adj_Close', 'xlu_pctChange',
#        'vpu_Adj_Close', 'vpu_pctChange', 'ryu_Adj_Close', 'ryu_pctChange',
#        'futy_Adj_Close', 'futy_pctChange', 'Nat Gas High', 'Nat Gas Low',
#        'Nat Gas Adj Close', 'Nat Gas pctChange', 'Crude Oil High',
#        'Crude Oil Low', 'Crude Oil Adj Close', 'Crude Oil pctChange'],
#       dtype='object')

# %% [markdown]
# ### Automatic Feature Reducer

# %%
# from sklearn.datasets import make_classification
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
# # from sklearn.feature_selection import RFECV

# %%
# rfe = RFECV(estimator=DecisionTreeRegressor())
# pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# %%
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')

# %% [markdown]
# ### VPU Seven day rolling window

# %%
# Adding predict column looking out 1 day
ml_df = ml_df.drop(columns="vpu_pred")
ml_df['vpu_pred_7day'] = ml_df.vpu_Adj_Close.shift(-7)
ml_df = ml_df.dropna()
ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_pctChange  Nat Gas High  Nat Gas Low  \
# 2013-10-25        9.000779  ...        0.010301         3.731        3.593
# 2013-10-28        8.908505  ...       -0.000785         3.681        3.557
# 2013-10-29        8.975615  ...        0.001963         3.589        3.480
# 2013-10-30        8.908505  ...       -0.005484         3.662        3.610
# 2013-10-31        8.883341  ...       -0.003939         3.659        3.560
#
#             Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25              3.707           0.021494       98.059998
# 2013-10-28              3.569          -0.037227       98.820000
# 2013-10-29              3.497          -0.020174       98.570000
# 2013-10-30              3.620           0.035173       97.820000
# 2013-10-31              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange  \
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
#             vpu_pred_7day
# 2013-10-25      66.689087
# 2013-10-28      67.465393
# 2013-10-29      66.822418
# 2013-10-30      66.791046
# 2013-10-31      66.775368
#
# [5 rows x 28 columns]

# %%
# Random Forest classification to check for feature importance

# Initial Random Forest Imports
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline
import pydotplus
from IPython.display import Image

# %%
# Define Features for vpu dataset
X = ml_df.copy()
X.drop('vpu_pred_7day', axis=1, inplace=True)
X.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
# 2013-10-31        8.883341  ...       19.829756       -0.003939         3.659
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
# 2013-10-31        3.560              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
# [5 rows x 27 columns]

# %%
len(X)
# Out:
# 1822

# %%
y = ml_df['vpu_pred_7day']

# %%
len(y)
# Out:
# 1822

# %%
# Splitting into Train and Test sets
split = int(0.7 * len(X))

X_train = X[: split]
X_test = X[split:]

y_train = y[: split]
y_test = y[split:]

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# Scaling data
X_train = X_scaler.transform(X_train)
X_test = X_scaler.transform(X_test)

# %%
len(X_test)
# Out:
# 547

# %%
len(y_test)
# Out:
# 547

# %%
#define model (try to n_features function for automation of df drop)
model = LinearRegression()
#fit model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: 0.10254
# Feature: 1, Score: 0.25813
# Feature: 2, Score: -0.06398
# Feature: 3, Score: 0.06360
# Feature: 4, Score: -0.00677
# Feature: 5, Score: 0.33417
# Feature: 6, Score: -0.05150
# Feature: 7, Score: -0.47523
# Feature: 8, Score: 0.05122
# Feature: 9, Score: -0.31439
# Feature: 10, Score: 0.01803
# Feature: 11, Score: -16.83823
# Feature: 12, Score: 0.62922
# Feature: 13, Score: 33.87119
# Feature: 14, Score: -0.37346
# Feature: 15, Score: 1.81574
# Feature: 16, Score: -0.32676
# Feature: 17, Score: -5.95019
# Feature: 18, Score: 0.00582
# Feature: 19, Score: -0.56964
# Feature: 20, Score: 0.98687
# Feature: 21, Score: -0.11217
# Feature: 22, Score: 0.06613
# Feature: 23, Score: 2.83547
# Feature: 24, Score: 3.10029
# Feature: 25, Score: -6.96482
# Feature: 26, Score: 0.16800

# %%
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

# %%
importances = importance

# %%
#sorting importances
sorted(zip(importances, X.columns), reverse=True)
# Out:
# [(33.87118961935841, 'vpu_Adj_Close'),
#  (3.1002934734000447, 'Crude Oil Low'),
#  (2.835465282040112, 'Crude Oil High'),
#  (1.815736175003286, 'ryu_Adj_Close'),
#  (0.9868687251848701, 'Nat Gas Low'),
#  (0.6292184017056279, 'xlu_pctChange'),
#  (0.33416838339374316, 'BTC Active Addresses'),
#  (0.258134189750164, 'BTC Volume'),
#  (0.16800316162352624, 'Crude Oil pctChange'),
#  (0.10254102421216008, 'temp_diff'),
#  (0.06612675534707839, 'Nat Gas pctChange'),
#  (0.06360339010218138, 'BTC New Coins Mined'),
#  (0.051224880169853874, 'BTC Daily Transactions Change (%)'),
#  (0.018026431218034808, 'icln_pctChange'),
#  (0.005816193883586521, 'futy_pctChange'),
#  (-0.006773326133743748, 'BTC New Coins Mined (%)'),
#  (-0.05150278397966592, 'BTC Daily Active Addresses Change (%)'),
#  (-0.06398292917068917, 'BTC Daily Volume Change (%)'),
#  (-0.11216522079056378, 'Nat Gas Adj Close'),
#  (-0.31439335927157247, 'icln_Adj_Close'),
#  (-0.3267629102006254, 'ryu_pctChange'),
#  (-0.3734598859895298, 'vpu_pctChange'),
#  (-0.47523341132350894, 'BTC Transactions'),
#  (-0.5696424353460056, 'Nat Gas High'),
#  (-5.950194853614441, 'futy_Adj_Close'),
#  (-6.96481566202267, 'Crude Oil Adj Close'),
#  (-16.83823393987343, 'xlu_Adj_Close')]

# %%
importances_df =pd.DataFrame(sorted(zip(importances, X.columns), reverse=True))
importances_df
# Out:
#             0                                      1
# 0   33.871190                          vpu_Adj_Close
# 1    3.100293                          Crude Oil Low
# 2    2.835465                         Crude Oil High
# 3    1.815736                          ryu_Adj_Close
# 4    0.986869                            Nat Gas Low
# 5    0.629218                          xlu_pctChange
# 6    0.334168                   BTC Active Addresses
# 7    0.258134                             BTC Volume
# 8    0.168003                    Crude Oil pctChange
# 9    0.102541                              temp_diff
# 10   0.066127                      Nat Gas pctChange
# 11   0.063603                    BTC New Coins Mined
# 12   0.051225      BTC Daily Transactions Change (%)
# 13   0.018026                         icln_pctChange
# 14   0.005816                         futy_pctChange
# 15  -0.006773                BTC New Coins Mined (%)
# 16  -0.051503  BTC Daily Active Addresses Change (%)
# 17  -0.063983            BTC Daily Volume Change (%)
# 18  -0.112165                      Nat Gas Adj Close
# 19  -0.314393                         icln_Adj_Close
# 20  -0.326763                          ryu_pctChange
# 21  -0.373460                          vpu_pctChange
# 22  -0.475233                       BTC Transactions
# 23  -0.569642                           Nat Gas High
# 24  -5.950195                         futy_Adj_Close
# 25  -6.964816                    Crude Oil Adj Close
# 26 -16.838234                          xlu_Adj_Close

# %%
# Visualize the features by importance
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <AxesSubplot:title={'center':'Features Importances'}, ylabel='1'>

# %%
# Making predictions using the testing data
predictions = model.predict(X_test)
predictions
# Out:
# array([115.93781038, 115.45440714, 116.24466691, 116.69663296,
#        117.10956159, 116.65743091, 117.48217416, 117.18719679,
#        113.50213948, 113.02456152, 112.75271242, 113.12824803,
#        112.90415234, 108.08614611, 109.80577472, 109.72306263,
#        109.80844323, 108.17042234, 108.07195637, 109.90013444,
#        109.09531673, 110.03622121, 109.29132184, 110.32064697,
#        110.30988086, 108.60429252, 109.39508982, 109.71345582,
#        110.64660759, 110.74964495, 110.14697372, 111.82662774,
#        112.65574913, 111.30678933, 110.1472869 , 110.81067719,
#        111.04073897, 112.80091056, 112.68447631, 112.65285479,
#        113.37078887, 112.82461159, 113.8706232 , 114.96867456,
#        114.19087482, 115.32034538, 114.86593445, 114.25490617,
#        115.01582722, 115.14001151, 115.73698348, 116.72989449,
#        117.36169138, 116.57154505, 116.13143412, 116.21381065,
#        116.65918777, 116.96422191, 117.49799526, 117.42924353,
#        117.02285992, 117.60606834, 117.84672422, 118.75555203,
#        119.59974462, 119.5307688 , 119.47321417, 119.89553523,
#        119.49334876, 118.47476031, 118.52841958, 119.8381594 ,
#        120.49796862, 120.4980644 , 121.08182546, 120.30795893,
#        119.06454139, 119.92341715, 118.65796284, 118.58414834,
#        118.87904751, 118.25796442, 118.9375973 , 118.27026905,
#        118.49633725, 118.09478992, 118.35893516, 119.47760006,
#        119.07180891, 117.88239229, 117.45377238, 117.416512  ,
#        117.01375265, 117.96655868, 118.65206596, 119.03400061,
#        119.07599269, 118.25507617, 120.37807965, 118.78978739,
#        118.34289875, 119.3553853 , 118.83125122, 119.11922745,
#        123.4724492 , 122.98670545, 123.10758572, 122.67716814,
#        122.64932225, 121.90417444, 123.88668275, 122.97190602,
#        123.54334833, 121.48918657, 120.36357174, 120.2206148 ,
#        119.33069175, 120.96661856, 120.7791553 , 121.1602966 ,
#        123.04203319, 120.62183936, 120.354492  , 122.51069458,
#        120.72394842, 120.96660504, 120.22384714, 120.18028492,
#        122.05664579, 121.31696347, 122.97342259, 122.10835789,
#        122.84914158, 121.3499674 , 120.9527629 , 123.40525165,
#        121.89524242, 119.84970975, 121.00810657, 120.531222  ,
#        121.7259869 , 122.01886972, 121.56360601, 122.7771875 ,
#        123.40161276, 122.95657078, 122.85051947, 123.56318509,
#        123.19576177, 122.33491543, 122.03003145])

# %%
Results = y_test
Out_of_sample_results = pd.DataFrame({"Actual_Results": y_test,
                   "Predicted Returns": predictions})

# %%
Out_of_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
Out_of_sample_results.head()
# Out:
#             Actual_Results  Predicted Returns
# 2018-12-04      116.298706         115.937810
# 2018-12-06      112.519936         115.454407
# 2018-12-07      111.714188         116.244667
# 2018-12-10      111.575249         116.696633
# 2018-12-11      111.760490         117.109562

# %%
#out of sample performance
out_of_sample_mse = mean_squared_error(
    Out_of_sample_results["Actual_Results"],
    Out_of_sample_results["Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

out_of_sample_rmse = np.sqrt(out_of_sample_mse)
r2 = r2_score(Out_of_sample_results["Actual_Results"], Out_of_sample_results["Predicted Returns"])

print(f"Out-of-sample Root Mean Squared Error (RMSE): {out_of_sample_rmse}")
print(f"Out-of-Sample r2: {r2}")
# Out:
# Out-of-sample Root Mean Squared Error (RMSE): 7.4857258458185445
# Out-of-Sample r2: 0.28914633356130937

# %%
Out_of_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
#In sample performance

in_sample_results = y_train

# Add a column of "in-sample" predictions to that dataframe:  
# YOUR CODE HERE!

in_sample_results = pd.DataFrame({"Actual_Results": y_train})

in_sample_results["in-sample predictions"] = model.predict(X_train)


# Calculate in-sample mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_mse = mean_squared_error(
    in_sample_results["Actual_Results"],
    in_sample_results["in-sample predictions"]
)

# Calculate in-sample root mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_rmse = np.sqrt(in_sample_mse)
r2_in = r2_score(in_sample_results["Actual_Results"], in_sample_results["in-sample predictions"])
print(f"In Sample Root Mean Squared Error (RMSE): {in_sample_rmse}")
print(f"In sample r2: {r2_in}")
# Out:
# In Sample Root Mean Squared Error (RMSE): 1.827591027209144
# In sample r2: 0.9814494820554707

# %%
in_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
#AutoRegressor library components
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std

# %%
#Recursive Feature Elimination logic
rfe = RFE(estimator=DecisionTreeRegressor(), n_features_to_select=5)
pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# %%
#Evaluate Model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')

# %%
#RFE performance. MAE = Mean Absolute Error
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MAE: -1.484 (0.098)

# %%
#re-running model with recursive feature elimination prediction
pipeline.fit(X_train, y_train)
yhat = pipeline.predict(X_test)

# %%
oos_pipeline_results = pd.DataFrame({"Actual_Results": y_test,
                   "Pipeline Predicted Returns": yhat})

# %%
oos_pipeline_results.head()
# Out:
#             Actual_Results  Pipeline Predicted Returns
# 2018-12-04      116.298706                  114.833664
# 2018-12-06      112.519936                  114.757384
# 2018-12-07      111.714188                  115.420831
# 2018-12-10      111.575249                  115.770064
# 2018-12-11      111.760490                  116.035281

# %%
#out of sample PIPELINE  performance
oos_pipeline_mse = mean_squared_error(
    oos_pipeline_results["Actual_Results"],
    oos_pipeline_results["Pipeline Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

oos_pipeline_mse = np.sqrt(oos_pipeline_mse)
r2 = r2_score(oos_pipeline_results["Actual_Results"], oos_pipeline_results["Pipeline Predicted Returns"])

print(f"Out-of-sample Pipeline Root Mean Squared Error (RMSE): {oos_pipeline_mse}")
print(f"Out-of-Sample Pipeline r2: {r2}")
# Out:
# Out-of-sample Pipeline Root Mean Squared Error (RMSE): 4.725275287409669
# Out-of-Sample Pipeline r2: 0.7167521628509237

# %%
oos_pipeline_results.plot()
# Out:
# <AxesSubplot:>

# %%
#Which features were selected
for i in range(X_train.shape[1]):
	print('Column: %d. Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0. Selected False, Rank: 9.000
# Column: 1. Selected False, Rank: 7.000
# Column: 2. Selected False, Rank: 11.000
# Column: 3. Selected False, Rank: 17.000
# Column: 4. Selected False, Rank: 21.000
# Column: 5. Selected False, Rank: 4.000
# Column: 6. Selected False, Rank: 23.000
# Column: 7. Selected False, Rank: 8.000
# Column: 8. Selected False, Rank: 19.000
# Column: 9. Selected False, Rank: 3.000
# Column: 10. Selected False, Rank: 18.000
# Column: 11. Selected True, Rank: 1.000
# Column: 12. Selected False, Rank: 20.000
# Column: 13. Selected True, Rank: 1.000
# Column: 14. Selected False, Rank: 22.000
# Column: 15. Selected True, Rank: 1.000
# Column: 16. Selected False, Rank: 16.000
# Column: 17. Selected True, Rank: 1.000
# Column: 18. Selected False, Rank: 13.000
# Column: 19. Selected True, Rank: 1.000
# Column: 20. Selected False, Rank: 6.000
# Column: 21. Selected False, Rank: 10.000
# Column: 22. Selected False, Rank: 14.000
# Column: 23. Selected False, Rank: 5.000
# Column: 24. Selected False, Rank: 2.000
# Column: 25. Selected False, Rank: 12.000
# Column: 26. Selected False, Rank: 15.000

# %%
X.columns
# Out:
# Index(['temp_diff', 'BTC Volume', 'BTC Daily Volume Change (%)',
#        'BTC New Coins Mined', 'BTC New Coins Mined (%)',
#        'BTC Active Addresses', 'BTC Daily Active Addresses Change (%)',
#        'BTC Transactions', 'BTC Daily Transactions Change (%)',
#        'icln_Adj_Close', 'icln_pctChange', 'xlu_Adj_Close', 'xlu_pctChange',
#        'vpu_Adj_Close', 'vpu_pctChange', 'ryu_Adj_Close', 'ryu_pctChange',
#        'futy_Adj_Close', 'futy_pctChange', 'Nat Gas High', 'Nat Gas Low',
#        'Nat Gas Adj Close', 'Nat Gas pctChange', 'Crude Oil High',
#        'Crude Oil Low', 'Crude Oil Adj Close', 'Crude Oil pctChange'],
#       dtype='object')
