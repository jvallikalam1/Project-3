# %%
# Initial imports
import pandas as pd
import seaborn as sns

from pathlib import Path

# %%
# 1. Weather DataFrame from NYC. 
weather_df = pd.read_csv(Path('data/weather_nyc_final.csv'), parse_dates=True, index_col='date')
weather_df.sort_index(ascending=True, inplace=True)

#weather_df.head()

# %%
# 2. Crypto DataFrame
crypto_df = pd.read_csv(Path('crypto.csv'), parse_dates=True, index_col='Date')
crypto_df.sort_index(ascending=True, inplace=True)

#crypto_df.head()
# Out:
#             BTC Volume  BTC Daily Volume Change (%)  BTC Supply  \
# Date
# 2009-01-03         0.0                          NaN        50.0
# 2009-01-04         0.0                          NaN        50.0
# 2009-01-05         0.0                          NaN        50.0
# 2009-01-06         0.0                          NaN        50.0
# 2009-01-07         0.0                          NaN        50.0
#
#             BTC Daily Ciculating Supply Change (%)  BTC Active Addresses  \
# Date
# 2009-01-03                                     NaN                     0
# 2009-01-04                                     0.0                     0
# 2009-01-05                                     0.0                     0
# 2009-01-06                                     0.0                     0
# 2009-01-07                                     0.0                     0
#
#             BTC Daily Active Addresses Change (%)  BTC Transactions  \
# Date
# ...

# %%
# 3. Energy Stock Ticker
stock_energy_df = pd.read_csv(Path('stocks.csv'), parse_dates=True, index_col='Date')
stock_energy_df.sort_index(ascending=True, inplace=True)
stock_energy_df.head()
# Out:
#              xle_Open   xle_High    xle_Low  xle_Close  xle_Adj_Close  \
# Date
# 2010-08-25  51.110001  51.400002  50.419998  51.240002      36.126720
# 2010-08-26  51.529999  51.700001  50.490002  50.779999      35.802399
# 2010-08-27  51.080002  52.200001  50.330002  52.099998      36.733067
# 2010-08-30  52.000000  52.240002  51.330002  51.340000      36.197224
# 2010-08-31  51.110001  51.599998  50.810001  51.200001      36.098518
#
#             xle_Volume  xle_pctChange  icln_Open  icln_High  icln_Low  ...  \
# Date                                                                   ...
# 2010-08-25    19336700      -0.003113      15.09      15.28     14.93  ...
# 2010-08-26    10976800      -0.008977      15.45      15.50     15.26  ...
# 2010-08-27    19708700       0.025995      15.47      15.76     15.35  ...
# 2010-08-30     9156600      -0.014587      15.57      15.78     15.45  ...
# 2010-08-31    17578700      -0.002727      15.45      15.65     15.45  ...
#
# ...

# %%
# 4. Commodities
commodities_df = pd.read_csv(Path('commodities.csv'), parse_dates=True, index_col='Date')
commodities_df.sort_index(ascending=True, inplace=True)
commodities_df.head()
# Out:
#             Nat Gas Open  Nat Gas High  Nat Gas Low  Nat Gas Close  \
# Date
# 2010-01-04         5.705         5.894        5.705          5.884
# 2010-01-05         5.837         5.858        5.615          5.637
# 2010-01-06         5.690         6.075        5.650          6.009
# 2010-01-07         6.033         6.108        5.763          5.806
# 2010-01-08         5.827         5.853        5.621          5.749
#
#             Nat Gas Adj Close  Nat Gas Volume  Nat Gas pctChange  \
# Date
# 2010-01-04              5.884           78858                NaN
# 2010-01-05              5.637           99492          -0.041978
# 2010-01-06              6.009          140611           0.065993
# 2010-01-07              5.806          135113          -0.033783
# 2010-01-08              5.749          101153          -0.009817
#
#             Crude Oil Open  Crude Oil High  Crude Oil Low  ...  \
# Date                                                       ...
# ...

# %%
# Define all the different data frames into a list
combined_frames = [weather_df,
              crypto_df,
              stock_energy_df,
              commodities_df]

# Concatenate all the dataframes into one
combined_df = pd.concat(combined_frames, axis=1, join='inner', ignore_index=False)
combined_df.head()
# Out:
#             temp_max  temp_avg  temp_min  dew_point_max  dew_point_avg  \
# 2010-08-25        71      67.3        64             65           63.4
# 2010-08-26        82      74.3        69             64           58.3
# 2010-08-27        78      71.8        64             54           50.9
# 2010-08-30        91      82.9        75             67           58.6
# 2010-08-31        95      86.5        79             66           62.9
#
#             dew_point_min  humidity_max  humidity_avg  humidity_min  wind_max  \
# 2010-08-25             61            94          87.2            78        13
# 2010-08-26             50            81          59.2            34        20
# 2010-08-27             47            67          48.8            35        13
# 2010-08-30             53            64          44.6            28        15
# 2010-08-31             60            60          46.2            31         9
#
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2622 entries, 2010-08-25 to 2021-02-26
# Data columns (total 83 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   temp_max                                2622 non-null   int64
#  1   temp_avg                                2622 non-null   float64
#  2   temp_min                                2622 non-null   int64
#  3   dew_point_max                           2622 non-null   int64
#  4   dew_point_avg                           2622 non-null   float64
#  5   dew_point_min                           2622 non-null   int64
#  6   humidity_max                            2622 non-null   int64
#  7   humidity_avg                            2622 non-null   float64
#  8   humidity_min                            2622 non-null   int64
#  9   wind_max                                2622 non-null   int64
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X, y)
importance = model.coef_[0]

# %%
 73  Corn Fut Adj Close                      2620 non-null   float64
 74  Corn Fut Volume                         2620 non-null   float64
 75  Corn Fut pctChange                      2620 non-null   float64

# %%
Maybe categorize into groups (low, med, high)
How to define good/bad weather? Maybe compared to the overall average for the regions over the last 50 years...

# %%
BTC Supply - take previous day minus current day = coins supplied for that day

# %%
# Calculate the correlation between all columns
weather_correlation = weather_df.corr()
weather_correlation
# Out:
#                temp_avg  dew_point_avg  humidity_avg  wind_avg
# temp_avg       1.000000       0.928533      0.105696 -0.359617
# dew_point_avg  0.928533       1.000000      0.457854 -0.356157
# humidity_avg   0.105696       0.457854      1.000000 -0.097835
# wind_avg      -0.359617      -0.356157     -0.097835  1.000000

# %%
# Use the `heatmap` function from the seaborn library to visualize correlations
sns.heatmap(weather_correlation, vmin=-1, vmax=1)
