# %%
# Initial imports
import pandas as pd
import seaborn as sns
import numpy as np
from pathlib import Path

# %%
# 1. Weather DataFrame from NYC. 
weather_df = pd.read_csv(Path('weather_nyc_final.csv'), parse_dates=True, index_col='date')
weather_df.sort_index(ascending=True, inplace=True)

weather_df.head()
# Out:
#             temp_diff
# date
# 2010-01-01        3.5
# 2010-01-02       -7.5
# 2010-01-03      -12.0
# 2010-01-04       -6.5
# 2010-01-05       -6.0

# %%
# 2. Crypto DataFrame
crypto_df = pd.read_csv(Path('crypto.csv'), parse_dates=True, index_col='Date')
crypto_df.sort_index(ascending=True, inplace=True)

crypto_df.head()
# Out:
#             BTC Volume  BTC Daily Volume Change (%)  BTC New Coins Mined  \
# Date
# 2009-01-03         0.0                          NaN                  NaN
# 2009-01-04         0.0                          NaN                  0.0
# 2009-01-05         0.0                          NaN                  0.0
# 2009-01-06         0.0                          NaN                  0.0
# 2009-01-07         0.0                          NaN                  0.0
#
#             BTC New Coins Mined (%)  BTC Active Addresses  \
# Date
# 2009-01-03                      NaN                     0
# 2009-01-04                      NaN                     0
# 2009-01-05                      NaN                     0
# 2009-01-06                      NaN                     0
# 2009-01-07                      NaN                     0
#
#             BTC Daily Active Addresses Change (%)  BTC Transactions  \
# Date
# 2009-01-03                                    NaN                 0
# 2009-01-04                                    NaN                 0
# 2009-01-05                                    NaN                 0
# 2009-01-06                                    NaN                 0
# 2009-01-07                                    NaN                 0
#
#             BTC Daily Transactions Change (%)
# Date
# 2009-01-03                                NaN
# 2009-01-04                                NaN
# 2009-01-05                                NaN
# 2009-01-06                                NaN
# 2009-01-07                                NaN

# %%
# 3. Energy Stock Ticker
stock_energy_df = pd.read_csv(Path('stocks_final.csv'), parse_dates=True, index_col='Date')
stock_energy_df.sort_index(ascending=True, inplace=True)
stock_energy_df.head()
# Out:
#             icln_Open  icln_High  icln_Low  icln_Close  icln_Adj_Close  \
# Date
# 2013-10-24      10.99      11.18     10.85       10.90        9.143383
# 2013-10-25      10.84      10.84     10.67       10.73        9.000779
# 2013-10-28      10.75      10.75     10.54       10.62        8.908505
# 2013-10-29      10.58      10.70     10.58       10.70        8.975615
# 2013-10-30      10.65      10.68     10.60       10.62        8.908505
#
#             icln_Volume  icln_pctChange   xlu_Open   xlu_High    xlu_Low  ...  \
# Date                                                                      ...
# 2013-10-24        41600       -0.004566  39.009998  39.009998  38.590000  ...
# 2013-10-25        17200       -0.015596  38.759998  39.230000  38.599998  ...
# 2013-10-28        57200       -0.010252  39.180000  39.349998  38.980000  ...
# 2013-10-29        22900        0.007533  39.110001  39.270000  39.020000  ...
# 2013-10-30        17100       -0.007477  39.240002  39.450001  38.880001  ...
#
#             ryu_Adj_Close  ryu_Volume  ryu_pctChange  futy_Open  futy_High  \
# Date
# 2013-10-24      50.859299        7100      -0.001546  25.250000  25.290001
# 2013-10-25      51.458099        5400       0.011774  25.240000  25.510000
# 2013-10-28      51.402939        2900      -0.001072  25.530001  25.600000
# 2013-10-29      51.505379        5700       0.001993  25.709999  25.709999
# 2013-10-30      51.166584        2800      -0.006578  25.590000  25.690001
#
#              futy_Low  futy_Close  futy_Adj_Close  futy_Volume  futy_pctChange
# Date
# 2013-10-24  25.170000   25.240000       19.790556        15500             NaN
# 2013-10-25  25.200001   25.500000       19.994419        14900        0.010301
# 2013-10-28  25.410000   25.480000       19.978731        39500       -0.000785
# 2013-10-29  25.440001   25.530001       20.017941        15600        0.001963
# 2013-10-30  25.360001   25.389999       19.908169       163500       -0.005484
#
# [5 rows x 35 columns]

# %%
# 4. Commodities
commodities_df = pd.read_csv(Path('commodities.csv'), parse_dates=True, index_col='Date')
commodities_df.sort_index(ascending=True, inplace=True)
commodities_df.head()
# Out:
#             Nat Gas Open  Nat Gas High  Nat Gas Low  Nat Gas Close  \
# Date
# 2010-01-04         5.705         5.894        5.705          5.884
# 2010-01-05         5.837         5.858        5.615          5.637
# 2010-01-06         5.690         6.075        5.650          6.009
# 2010-01-07         6.033         6.108        5.763          5.806
# 2010-01-08         5.827         5.853        5.621          5.749
#
#             Nat Gas Adj Close  Nat Gas Volume  Nat Gas pctChange  \
# Date
# 2010-01-04              5.884           78858                NaN
# 2010-01-05              5.637           99492          -0.041978
# 2010-01-06              6.009          140611           0.065993
# 2010-01-07              5.806          135113          -0.033783
# 2010-01-08              5.749          101153          -0.009817
#
#             Crude Oil Open  Crude Oil High  Crude Oil Low  ...  \
# Date                                                       ...
# 2010-01-04       79.629997       81.680000      79.629997  ...
# 2010-01-05       81.629997       82.000000      80.949997  ...
# 2010-01-06       81.430000       83.519997      80.849998  ...
# 2010-01-07       83.199997       83.360001      82.260002  ...
# 2010-01-08       82.650002       83.470001      81.800003  ...
#
#             Corn Fut Adj Close  Corn Fut Volume  Corn Fut pctChange  \
# Date
# 2010-01-04              418.50         140553.0                 NaN
# 2010-01-05              418.75          80967.0            0.000597
# 2010-01-06              421.75          96453.0            0.007164
# 2010-01-07              417.50         137395.0           -0.010077
# 2010-01-08              423.00         137395.0            0.013174
#
#             SB Fut Open  SB Fut High  SB Fut Low  SB Fut Close  \
# Date
# 2010-01-04      1043.00      1065.50     1041.25       1049.50
# 2010-01-05      1047.00      1056.00     1042.00       1052.25
# 2010-01-06      1050.00      1058.50     1042.75       1050.50
# 2010-01-07      1050.50      1052.00     1016.50       1017.75
# 2010-01-08      1018.25      1018.25     1005.00       1013.00
#
#             SB Fut Adj Close  SB Fut Volume  SB Fut pctChange
# Date
# 2010-01-04           1049.50          25947               NaN
# 2010-01-05           1052.25          21073          0.002620
# 2010-01-06           1050.50          17567         -0.001663
# 2010-01-07           1017.75          11750         -0.031176
# 2010-01-08           1013.00          11750         -0.004667
#
# [5 rows x 28 columns]

# %%
# Define all the different data frames into a list
combined_frames = [weather_df,
              crypto_df,
              stock_energy_df,
              commodities_df]

# Concatenate all the dataframes into one
combined_df = pd.concat(combined_frames, axis=1, join='inner', ignore_index=False)
combined_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-24       -8.5  1.023678e+06                    -0.056652
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-24               5375.0                -0.027149
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-24                111582                               0.042199
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
#
#             BTC Transactions  BTC Daily Transactions Change (%)  icln_Open  \
# 2013-10-24             63419                           0.151126      10.99
# 2013-10-25             57236                          -0.097494      10.84
# 2013-10-28             50929                           0.170459      10.75
# 2013-10-29             49770                          -0.022757      10.58
# 2013-10-30             48251                          -0.030520      10.65
#
#             ...  Corn Fut Adj Close  Corn Fut Volume  Corn Fut pctChange  \
# 2013-10-24  ...              440.25         145523.0           -0.005647
# 2013-10-25  ...              440.00         114537.0           -0.000568
# 2013-10-28  ...              430.75         197956.0           -0.021023
# 2013-10-29  ...              432.00         160427.0            0.002902
# 2013-10-30  ...              430.25         145107.0           -0.004051
#
#             SB Fut Open  SB Fut High  SB Fut Low  SB Fut Close  \
# 2013-10-24       1309.0      1318.00     1306.00       1309.75
# 2013-10-25       1309.0      1312.75     1299.25       1300.00
# 2013-10-28       1300.0      1301.25     1270.25       1271.25
# 2013-10-29       1270.0      1280.50     1268.00       1279.00
# 2013-10-30       1279.0      1292.50     1279.00       1287.50
#
#             SB Fut Adj Close  SB Fut Volume  SB Fut pctChange
# 2013-10-24           1309.75         111457         -0.000191
# 2013-10-25           1300.00         104191         -0.007444
# 2013-10-28           1271.25         124280         -0.022115
# 2013-10-29           1279.00          95488          0.006096
# 2013-10-30           1287.50          72297          0.006646
#
# [5 rows x 72 columns]

# %%
# combined_df.info()

# %%
# Copy combined df to create ALL potential features dataset
potential_feature_df = combined_df.copy()
potential_feature_df.drop(
                                    [
                                    'icln_Open',
                                    'icln_High',
                                    'icln_Low',
                                    'xlu_Open',
                                    'xlu_High',
                                    'xlu_Low',
                                    'vpu_Open',
                                    'vpu_High',
                                    'vpu_Low',
                                    'ryu_Open',
                                    'ryu_High',
                                    'ryu_Low',
                                    'futy_Open',
                                    'futy_High',
                                    'futy_Low',
                                    'Corn Fut Open',
                                    'Corn Fut High',
                                    'Corn Fut Low',
                                    'SB Fut Open',
                                    'SB Fut High',
                                    'SB Fut Low',
                                   ],
                                axis=1, inplace=True)

potential_feature_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-24       -8.5  1.023678e+06                    -0.056652
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-24               5375.0                -0.027149
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-24                111582                               0.042199
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
#
#             BTC Transactions  BTC Daily Transactions Change (%)  icln_Close  \
# 2013-10-24             63419                           0.151126       10.90
# 2013-10-25             57236                          -0.097494       10.73
# 2013-10-28             50929                           0.170459       10.62
# 2013-10-29             49770                          -0.022757       10.70
# 2013-10-30             48251                          -0.030520       10.62
#
#             ...  Crude Oil Volume  Crude Oil pctChange  Corn Fut Close  \
# 2013-10-24  ...            248742             0.002581          440.25
# 2013-10-25  ...            192632             0.007620          440.00
# 2013-10-28  ...            230155             0.008482          430.75
# 2013-10-29  ...            183243            -0.004864          432.00
# 2013-10-30  ...            268138            -0.014562          430.25
#
#             Corn Fut Adj Close  Corn Fut Volume  Corn Fut pctChange  \
# 2013-10-24              440.25         145523.0           -0.005647
# 2013-10-25              440.00         114537.0           -0.000568
# 2013-10-28              430.75         197956.0           -0.021023
# 2013-10-29              432.00         160427.0            0.002902
# 2013-10-30              430.25         145107.0           -0.004051
#
#             SB Fut Close  SB Fut Adj Close  SB Fut Volume  SB Fut pctChange
# 2013-10-24       1309.75           1309.75         111457         -0.000191
# 2013-10-25       1300.00           1300.00         104191         -0.007444
# 2013-10-28       1271.25           1271.25         124280         -0.022115
# 2013-10-29       1279.00           1279.00          95488          0.006096
# 2013-10-30       1287.50           1287.50          72297          0.006646
#
# [5 rows x 51 columns]

# %%
# Copy combined df to create ALL potential features dataset
ml_df = potential_feature_df.copy()
ml_df.drop(
                                    [
                                    'icln_Close',
                                    'icln_Volume',
                                    'xlu_Close',
                                    'xlu_Volume',
                                    'vpu_Close',
                                    'vpu_Volume',
                                    'ryu_Close',
                                    'ryu_Volume',
                                    'futy_Close',
                                    'futy_Volume',
                                    'Nat Gas Open',
                                    'Nat Gas Close',
                                    'Nat Gas Volume',
                                    'Crude Oil Open',
                                    'Crude Oil Close',
                                    'Crude Oil Volume',
                                    'Corn Fut Close',
                                    'Corn Fut Adj Close',
                                    'Corn Fut Volume',
                                    'Corn Fut pctChange',
                                    'SB Fut Close',
                                    'SB Fut Adj Close',
                                    'SB Fut Volume',
                                    'SB Fut pctChange'
                                   ],
                                axis=1, inplace=True)

ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-24       -8.5  1.023678e+06                    -0.056652
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-24               5375.0                -0.027149
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-24                111582                               0.042199
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-24             63419                           0.151126
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-24        9.143383  ...       19.790556             NaN         3.645
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-24        3.545              3.629           0.002763       97.690002
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-24      95.949997            97.110001             0.002581
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
#
# [5 rows x 27 columns]

# %%
# Check for no null values
ml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1831 entries, 2013-10-24 to 2021-02-26
# Data columns (total 27 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   temp_diff                              1831 non-null   float64
#  1   BTC Volume                             1831 non-null   float64
#  2   BTC Daily Volume Change (%)            1831 non-null   float64
#  3   BTC New Coins Mined                    1831 non-null   float64
#  4   BTC New Coins Mined (%)                1831 non-null   float64
#  5   BTC Active Addresses                   1831 non-null   int64
#  6   BTC Daily Active Addresses Change (%)  1831 non-null   float64
#  7   BTC Transactions                       1831 non-null   int64
#  8   BTC Daily Transactions Change (%)      1831 non-null   float64
#  9   icln_Adj_Close                         1831 non-null   float64
#  10  icln_pctChange                         1831 non-null   float64
#  11  xlu_Adj_Close                          1831 non-null   float64
#  12  xlu_pctChange                          1831 non-null   float64
#  13  vpu_Adj_Close                          1831 non-null   float64
#  14  vpu_pctChange                          1831 non-null   float64
#  15  ryu_Adj_Close                          1831 non-null   float64
#  16  ryu_pctChange                          1831 non-null   float64
#  17  futy_Adj_Close                         1831 non-null   float64
#  18  futy_pctChange                         1830 non-null   float64
#  19  Nat Gas High                           1831 non-null   float64
#  20  Nat Gas Low                            1831 non-null   float64
#  21  Nat Gas Adj Close                      1831 non-null   float64
#  22  Nat Gas pctChange                      1831 non-null   float64
#  23  Crude Oil High                         1831 non-null   float64
#  24  Crude Oil Low                          1831 non-null   float64
#  25  Crude Oil Adj Close                    1831 non-null   float64
#  26  Crude Oil pctChange                    1831 non-null   float64
# dtypes: float64(25), int64(2)
# memory usage: 400.5 KB

# %%
ml_df.dropna(axis=0, inplace=True)
ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
# 2013-10-31        8.883341  ...       19.829756       -0.003939         3.659
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
# 2013-10-31        3.560              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
# [5 rows x 27 columns]

# %% [markdown]
# ### ICLN One day rolling window

# %%
# Adding predict column looking out 1 day
ml_df['icln_pred'] = ml_df.icln_Adj_Close.shift(-1)
ml_df = ml_df.dropna()
ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_pctChange  Nat Gas High  Nat Gas Low  \
# 2013-10-25        9.000779  ...        0.010301         3.731        3.593
# 2013-10-28        8.908505  ...       -0.000785         3.681        3.557
# 2013-10-29        8.975615  ...        0.001963         3.589        3.480
# 2013-10-30        8.908505  ...       -0.005484         3.662        3.610
# 2013-10-31        8.883341  ...       -0.003939         3.659        3.560
#
#             Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25              3.707           0.021494       98.059998
# 2013-10-28              3.569          -0.037227       98.820000
# 2013-10-29              3.497          -0.020174       98.570000
# 2013-10-30              3.620           0.035173       97.820000
# 2013-10-31              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange  icln_pred
# 2013-10-25      96.989998            97.849998             0.007620   8.908505
# 2013-10-28      97.370003            98.680000             0.008482   8.975615
# 2013-10-29      97.690002            98.199997            -0.004864   8.908505
# 2013-10-30      96.550003            96.769997            -0.014562   8.883341
# 2013-10-31      96.029999            96.379997            -0.004030   8.908505
#
# [5 rows x 28 columns]

# %%
# Random Forest classification to check for feature importance

# Initial Random Forest Imports
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline
import pydotplus
from IPython.display import Image

# %%
# Define Features for xle dataset
X = ml_df.copy()
X.drop('icln_pred', axis=1, inplace=True)
X.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
# 2013-10-31        8.883341  ...       19.829756       -0.003939         3.659
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
# 2013-10-31        3.560              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
# [5 rows x 27 columns]

# %%
len(X)
# Out:
# 1829

# %%
y = ml_df['icln_pred']

# %%
len(y)
# Out:
# 1829

# %%
# Splitting into Train and Test sets
split = int(0.7 * len(X))

X_train = X[: split]
X_test = X[split:]

y_train = y[: split]
y_test = y[split:]

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# Scaling data
X_train = X_scaler.transform(X_train)
X_test = X_scaler.transform(X_test)

# %%
len(X_test)
# Out:
# 549

# %%
len(y_test)
# Out:
# 549

# %%
#define model (try to n_features function for automation of df drop)
model = LinearRegression()
#fit model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: -0.00399
# Feature: 1, Score: 0.00575
# Feature: 2, Score: 0.00122
# Feature: 3, Score: -0.00514
# Feature: 4, Score: -0.00064
# Feature: 5, Score: 0.01547
# Feature: 6, Score: -0.00549
# Feature: 7, Score: -0.01627
# Feature: 8, Score: 0.00298
# Feature: 9, Score: 0.79804
# Feature: 10, Score: 0.00515
# Feature: 11, Score: -0.01525
# Feature: 12, Score: -0.00323
# Feature: 13, Score: -0.44851
# Feature: 14, Score: 0.02718
# Feature: 15, Score: 0.01848
# Feature: 16, Score: -0.01215
# Feature: 17, Score: 0.44136
# Feature: 18, Score: -0.01671
# Feature: 19, Score: -0.01097
# Feature: 20, Score: -0.04181
# Feature: 21, Score: 0.05398
# Feature: 22, Score: -0.00450
# Feature: 23, Score: 0.11732
# Feature: 24, Score: 0.05868
# Feature: 25, Score: -0.16412
# Feature: 26, Score: 0.00587

# %%
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

# %%
importances = importance

# %%
#sorting importances
sorted(zip(importances, X.columns), reverse=True)
# Out:
# [(0.7980403857805527, 'icln_Adj_Close'),
#  (0.4413629462109363, 'futy_Adj_Close'),
#  (0.11732223273454342, 'Crude Oil High'),
#  (0.05868219842656174, 'Crude Oil Low'),
#  (0.05398020198509062, 'Nat Gas Adj Close'),
#  (0.027184522136135234, 'vpu_pctChange'),
#  (0.018483079068498758, 'ryu_Adj_Close'),
#  (0.015469881057661077, 'BTC Active Addresses'),
#  (0.005870148669117854, 'Crude Oil pctChange'),
#  (0.005747856727330798, 'BTC Volume'),
#  (0.005153394608452872, 'icln_pctChange'),
#  (0.002981854073991899, 'BTC Daily Transactions Change (%)'),
#  (0.0012162646155814637, 'BTC Daily Volume Change (%)'),
#  (-0.0006362367014505996, 'BTC New Coins Mined (%)'),
#  (-0.003234567019749306, 'xlu_pctChange'),
#  (-0.003985720055311926, 'temp_diff'),
#  (-0.004497595613428894, 'Nat Gas pctChange'),
#  (-0.005135713071734114, 'BTC New Coins Mined'),
#  (-0.005494341944862269, 'BTC Daily Active Addresses Change (%)'),
#  (-0.010967426454754075, 'Nat Gas High'),
#  (-0.01215185826734813, 'ryu_pctChange'),
#  (-0.015251077972767677, 'xlu_Adj_Close'),
#  (-0.01626500801441726, 'BTC Transactions'),
#  (-0.01671124377645256, 'futy_pctChange'),
#  (-0.04181262460311575, 'Nat Gas Low'),
#  (-0.16412287086434668, 'Crude Oil Adj Close'),
#  (-0.448508439028269, 'vpu_Adj_Close')]

# %%
importances_df =pd.DataFrame(sorted(zip(importances, X.columns), reverse=True))
importances_df
# Out:
#            0                                      1
# 0   0.798040                         icln_Adj_Close
# 1   0.441363                         futy_Adj_Close
# 2   0.117322                         Crude Oil High
# 3   0.058682                          Crude Oil Low
# 4   0.053980                      Nat Gas Adj Close
# 5   0.027185                          vpu_pctChange
# 6   0.018483                          ryu_Adj_Close
# 7   0.015470                   BTC Active Addresses
# 8   0.005870                    Crude Oil pctChange
# 9   0.005748                             BTC Volume
# 10  0.005153                         icln_pctChange
# 11  0.002982      BTC Daily Transactions Change (%)
# 12  0.001216            BTC Daily Volume Change (%)
# 13 -0.000636                BTC New Coins Mined (%)
# 14 -0.003235                          xlu_pctChange
# 15 -0.003986                              temp_diff
# 16 -0.004498                      Nat Gas pctChange
# 17 -0.005136                    BTC New Coins Mined
# 18 -0.005494  BTC Daily Active Addresses Change (%)
# 19 -0.010967                           Nat Gas High
# 20 -0.012152                          ryu_pctChange
# 21 -0.015251                          xlu_Adj_Close
# 22 -0.016265                       BTC Transactions
# 23 -0.016711                         futy_pctChange
# 24 -0.041813                            Nat Gas Low
# 25 -0.164123                    Crude Oil Adj Close
# 26 -0.448508                          vpu_Adj_Close

# %%
# Visualize the features by importance
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <AxesSubplot:title={'center':'Features Importances'}, ylabel='1'>

# %%
# Making predictions using the testing data
predictions = model.predict(X_test)
predictions
# Out:
# array([ 8.53704649,  8.40362092,  8.42606188,  8.22486124,  8.1802896 ,
#         8.08993336,  7.98838166,  7.79738264,  8.03879927,  7.97774863,
#         8.00936063,  8.05049851,  8.0981981 ,  8.01263765,  8.26992008,
#         8.34865675,  8.41463249,  8.49776782,  8.57583752,  8.64301096,
#         8.60317553,  8.55294571,  8.57209775,  8.70654646,  8.70553409,
#         8.60016736,  8.69178759,  8.88813077,  8.95792473,  8.89968162,
#         9.00202198,  9.05923448,  9.21823659,  9.24085299,  9.20474427,
#         9.27350971,  9.21432892,  9.11141884,  9.09542374,  9.17337208,
#         9.28543849,  9.29930016,  9.3618639 ,  9.31582781,  9.38728396,
#         9.34230317,  9.3964513 ,  9.47819191,  9.51537907,  9.53629691,
#         9.48195473,  9.40709535,  9.40685895,  9.42621526,  9.51096636,
#         9.37883676,  9.24826618,  9.22605052,  9.43966098,  9.52684811,
#        20.57695183, 20.49594189, 20.35375354, 20.76533658, 19.84854181,
#        19.79181505, 19.84921116, 19.44071353, 19.29818903, 19.01340485,
#        19.38399406, 19.22167836, 19.54836986, 19.77955603, 19.53438058,
#        20.928201  , 21.05436907, 21.08598872, 20.76786402, 21.45691654,
#        21.19977278, 21.28497782, 21.43157925, 21.46637542, 21.16063195,
#        21.47121677, 21.69221463, 22.10473164, 22.41374899, 22.79645008,
#        23.09964   , 22.85721551, 22.67634518, 22.52979875, 22.59770085,
#        22.69802114, 23.30702818, 22.71850165, 23.09194942, 23.19369942,
#        23.53387023, 24.63176472, 24.6395035 , 25.12606193, 25.4623843 ,
#        25.91670774, 26.84516047, 27.2683173 , 27.44476378, 27.15195635,
#        27.79828045, 27.72198665, 28.18268689, 28.77895423, 30.84820371,
#        32.83348411, 32.55131805, 31.45293048, 31.84470478, 31.97826955,
#        31.70308685, 29.96798227, 30.8471872 , 30.71506055, 32.08838328,
#        32.29247384, 31.87053447, 31.5651476 , 29.58227928, 30.27314848,
#        29.26702768, 29.92605589, 30.23905771, 30.79774089, 30.38293093,
#        30.61550305, 30.94421176, 30.65165583, 30.23150232, 30.40715944,
#        29.76973835, 29.44891136, 28.95564548, 27.45891786, 28.01098031,
#        26.15193139, 25.78612221, 26.34753755, 25.06714684])

# %%
Results = y_test
Out_of_sample_results = pd.DataFrame({"Actual_Results": y_test,
                   "Predicted Returns": predictions})

# %%
Out_of_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
Out_of_sample_results.head()
# Out:
#             Actual_Results  Predicted Returns
# 2018-12-12        8.416711           8.537046
# 2018-12-13        8.426331           8.403621
# 2018-12-14        8.224329           8.426062
# 2018-12-17        8.180505           8.224861
# 2018-12-18        8.083118           8.180290

# %%
#out of sample performance
out_of_sample_mse = mean_squared_error(
    Out_of_sample_results["Actual_Results"],
    Out_of_sample_results["Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

out_of_sample_rmse = np.sqrt(out_of_sample_mse)
r2 = r2_score(Out_of_sample_results["Actual_Results"], Out_of_sample_results["Predicted Returns"])

print(f"Out-of-sample Root Mean Squared Error (RMSE): {out_of_sample_rmse}")
print(f"Out-of-Sample r2: {r2}")
# Out:
# Out-of-sample Root Mean Squared Error (RMSE): 0.39407112446557135
# Out-of-Sample r2: 0.9957930421533085

# %%
Out_of_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
#In sample performance

in_sample_results = y_train

# Add a column of "in-sample" predictions to that dataframe:  
# YOUR CODE HERE!

in_sample_results = pd.DataFrame({"Actual_Results": y_train})

in_sample_results["in-sample predictions"] = model.predict(X_train)


# Calculate in-sample mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_mse = mean_squared_error(
    in_sample_results["Actual_Results"],
    in_sample_results["in-sample predictions"]
)

# Calculate in-sample root mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_rmse = np.sqrt(in_sample_mse)
r2_in = r2_score(in_sample_results["Actual_Results"], in_sample_results["in-sample predictions"])
print(f"In Sample Root Mean Squared Error (RMSE): {in_sample_rmse}")
print(f"In sample r2: {r2_in}")
# Out:
# In Sample Root Mean Squared Error (RMSE): 0.10901449791991284
# In sample r2: 0.9820075107027094

# %%
in_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
#AutoRegressor library components
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std

# %%
#Recursive Feature Elimination logic
rfe = RFE(estimator=DecisionTreeRegressor(), n_features_to_select=5)
pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# %%
#Evaluate Model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')

# %%
#RFE performance. MAE = Mean Absolute Error
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MAE: -0.082 (0.005)

# %%
#re-running model with recursive feature elimination prediction
pipeline.fit(X_train, y_train)
yhat = pipeline.predict(X_test)

# %%
oos_pipeline_results = pd.DataFrame({"Actual_Results": y_test,
                   "Pipeline Predicted Returns": yhat})

# %%
oos_pipeline_results.head()
# Out:
#             Actual_Results  Pipeline Predicted Returns
# 2018-12-12        8.416711                    8.526191
# 2018-12-13        8.426331                    8.412241
# 2018-12-14        8.224329                    8.425935
# 2018-12-17        8.180505                    8.216704
# 2018-12-18        8.083118                    8.181012

# %%
#out of sample PIPELINE  performance
oos_pipeline_mse = mean_squared_error(
    oos_pipeline_results["Actual_Results"],
    oos_pipeline_results["Pipeline Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

oos_pipeline_mse = np.sqrt(oos_pipeline_mse)
r2 = r2_score(oos_pipeline_results["Actual_Results"], oos_pipeline_results["Pipeline Predicted Returns"])

print(f"Out-of-sample Pipeline Root Mean Squared Error (RMSE): {oos_pipeline_mse}")
print(f"Out-of-Sample Pipeline r2: {r2}")
# Out:
# Out-of-sample Pipeline Root Mean Squared Error (RMSE): 0.37821108849081836
# Out-of-Sample Pipeline r2: 0.9961248595369631

# %%
oos_pipeline_results.plot()
# Out:
# <AxesSubplot:>

# %%
#Which features were selected
for i in range(X_train.shape[1]):
	print('Column: %d. Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0. Selected False, Rank: 8.000
# Column: 1. Selected False, Rank: 7.000
# Column: 2. Selected False, Rank: 3.000
# Column: 3. Selected False, Rank: 16.000
# Column: 4. Selected False, Rank: 2.000
# Column: 5. Selected False, Rank: 23.000
# Column: 6. Selected False, Rank: 12.000
# Column: 7. Selected True, Rank: 1.000
# Column: 8. Selected False, Rank: 14.000
# Column: 9. Selected True, Rank: 1.000
# Column: 10. Selected True, Rank: 1.000
# Column: 11. Selected False, Rank: 11.000
# Column: 12. Selected False, Rank: 6.000
# Column: 13. Selected False, Rank: 18.000
# Column: 14. Selected False, Rank: 21.000
# Column: 15. Selected False, Rank: 19.000
# Column: 16. Selected False, Rank: 15.000
# Column: 17. Selected True, Rank: 1.000
# Column: 18. Selected False, Rank: 22.000
# Column: 19. Selected False, Rank: 10.000
# Column: 20. Selected False, Rank: 4.000
# Column: 21. Selected False, Rank: 17.000
# Column: 22. Selected False, Rank: 5.000
# Column: 23. Selected False, Rank: 13.000
# Column: 24. Selected False, Rank: 20.000
# Column: 25. Selected True, Rank: 1.000
# Column: 26. Selected False, Rank: 9.000

# %%
X.columns
# Out:
# Index(['temp_diff', 'BTC Volume', 'BTC Daily Volume Change (%)',
#        'BTC New Coins Mined', 'BTC New Coins Mined (%)',
#        'BTC Active Addresses', 'BTC Daily Active Addresses Change (%)',
#        'BTC Transactions', 'BTC Daily Transactions Change (%)',
#        'icln_Adj_Close', 'icln_pctChange', 'xlu_Adj_Close', 'xlu_pctChange',
#        'vpu_Adj_Close', 'vpu_pctChange', 'ryu_Adj_Close', 'ryu_pctChange',
#        'futy_Adj_Close', 'futy_pctChange', 'Nat Gas High', 'Nat Gas Low',
#        'Nat Gas Adj Close', 'Nat Gas pctChange', 'Crude Oil High',
#        'Crude Oil Low', 'Crude Oil Adj Close', 'Crude Oil pctChange'],
#       dtype='object')

# %% [markdown]
# ### Automatic Feature Reducer

# %%
# from sklearn.datasets import make_classification
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
# # from sklearn.feature_selection import RFECV

# %%
# rfe = RFECV(estimator=DecisionTreeRegressor())
# pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# %%
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')

# %% [markdown]
# ### ICLN Seven day rolling window

# %%
# Adding predict column looking out 1 day
ml_df = ml_df.drop(columns="icln_pred")
ml_df['icln_pred_7day'] = ml_df.icln_Adj_Close.shift(-7)
ml_df = ml_df.dropna()
ml_df.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_pctChange  Nat Gas High  Nat Gas Low  \
# 2013-10-25        9.000779  ...        0.010301         3.731        3.593
# 2013-10-28        8.908505  ...       -0.000785         3.681        3.557
# 2013-10-29        8.975615  ...        0.001963         3.589        3.480
# 2013-10-30        8.908505  ...       -0.005484         3.662        3.610
# 2013-10-31        8.883341  ...       -0.003939         3.659        3.560
#
#             Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25              3.707           0.021494       98.059998
# 2013-10-28              3.569          -0.037227       98.820000
# 2013-10-29              3.497          -0.020174       98.570000
# 2013-10-30              3.620           0.035173       97.820000
# 2013-10-31              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange  \
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
#             icln_pred_7day
# 2013-10-25        9.059497
# 2013-10-28        9.126607
# 2013-10-29        8.807844
# 2013-10-30        8.925283
# 2013-10-31        8.942060
#
# [5 rows x 28 columns]

# %%
# Random Forest classification to check for feature importance

# Initial Random Forest Imports
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline
import pydotplus
from IPython.display import Image

# %%
# Define Features for xle dataset
X = ml_df.copy()
X.drop('icln_pred_7day', axis=1, inplace=True)
X.head()
# Out:
#             temp_diff    BTC Volume  BTC Daily Volume Change (%)  \
# 2013-10-25       -9.0  2.811542e+06                     1.746512
# 2013-10-28       -4.0  6.413073e+05                     0.269235
# 2013-10-29       -8.0  1.682394e+06                     1.623382
# 2013-10-30       -3.5  7.121884e+05                    -0.576682
# 2013-10-31        2.5  6.799633e+05                    -0.045248
#
#             BTC New Coins Mined  BTC New Coins Mined (%)  \
# 2013-10-25               5875.0                 0.093023
# 2013-10-28               4375.0                -0.022346
# 2013-10-29               4000.0                -0.085714
# 2013-10-30               4875.0                 0.218750
# 2013-10-31               5275.0                 0.082051
#
#             BTC Active Addresses  BTC Daily Active Addresses Change (%)  \
# 2013-10-25                100390                              -0.100303
# 2013-10-28                 85464                               0.327328
# 2013-10-29                 84684                              -0.009127
# 2013-10-30                 94473                               0.115594
# 2013-10-31                 95831                               0.014374
#
#             BTC Transactions  BTC Daily Transactions Change (%)  \
# 2013-10-25             57236                          -0.097494
# 2013-10-28             50929                           0.170459
# 2013-10-29             49770                          -0.022757
# 2013-10-30             48251                          -0.030520
# 2013-10-31             57970                           0.201426
#
#             icln_Adj_Close  ...  futy_Adj_Close  futy_pctChange  Nat Gas High  \
# 2013-10-25        9.000779  ...       19.994419        0.010301         3.731
# 2013-10-28        8.908505  ...       19.978731       -0.000785         3.681
# 2013-10-29        8.975615  ...       20.017941        0.001963         3.589
# 2013-10-30        8.908505  ...       19.908169       -0.005484         3.662
# 2013-10-31        8.883341  ...       19.829756       -0.003939         3.659
#
#             Nat Gas Low  Nat Gas Adj Close  Nat Gas pctChange  Crude Oil High  \
# 2013-10-25        3.593              3.707           0.021494       98.059998
# 2013-10-28        3.557              3.569          -0.037227       98.820000
# 2013-10-29        3.480              3.497          -0.020174       98.570000
# 2013-10-30        3.610              3.620           0.035173       97.820000
# 2013-10-31        3.560              3.581          -0.010773       97.029999
#
#             Crude Oil Low  Crude Oil Adj Close  Crude Oil pctChange
# 2013-10-25      96.989998            97.849998             0.007620
# 2013-10-28      97.370003            98.680000             0.008482
# 2013-10-29      97.690002            98.199997            -0.004864
# 2013-10-30      96.550003            96.769997            -0.014562
# 2013-10-31      96.029999            96.379997            -0.004030
#
# [5 rows x 27 columns]

# %%
len(X)
# Out:
# 1822

# %%
y = ml_df['icln_pred_7day']

# %%
len(y)
# Out:
# 1822

# %%
# Splitting into Train and Test sets
split = int(0.7 * len(X))

X_train = X[: split]
X_test = X[split:]

y_train = y[: split]
y_test = y[split:]

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# Scaling data
X_train = X_scaler.transform(X_train)
X_test = X_scaler.transform(X_test)

# %%
len(X_test)
# Out:
# 547

# %%
len(y_test)
# Out:
# 547

# %%
#define model (try to n_features function for automation of df drop)
model = LinearRegression()
#fit model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: -0.02766
# Feature: 1, Score: -0.00842
# Feature: 2, Score: -0.00175
# Feature: 3, Score: 0.00192
# Feature: 4, Score: 0.00182
# Feature: 5, Score: 0.09896
# Feature: 6, Score: -0.01088
# Feature: 7, Score: -0.09278
# Feature: 8, Score: 0.01444
# Feature: 9, Score: 0.71158
# Feature: 10, Score: 0.00595
# Feature: 11, Score: 0.50308
# Feature: 12, Score: 0.00371
# Feature: 13, Score: -2.84224
# Feature: 14, Score: 0.04448
# Feature: 15, Score: 0.02645
# Feature: 16, Score: -0.01637
# Feature: 17, Score: 2.31682
# Feature: 18, Score: -0.05330
# Feature: 19, Score: 0.29531
# Feature: 20, Score: -0.09459
# Feature: 21, Score: -0.19495
# Feature: 22, Score: 0.00624
# Feature: 23, Score: 0.20180
# Feature: 24, Score: -0.49246
# Feature: 25, Score: 0.37038
# Feature: 26, Score: 0.00227

# %%
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

# %%
importances = importance

# %%
#sorting importances
sorted(zip(importances, X.columns), reverse=True)
# Out:
# [(2.316817682344526, 'futy_Adj_Close'),
#  (0.7115774278509741, 'icln_Adj_Close'),
#  (0.5030843909363568, 'xlu_Adj_Close'),
#  (0.3703753319866311, 'Crude Oil Adj Close'),
#  (0.29531121936657384, 'Nat Gas High'),
#  (0.20179931235613746, 'Crude Oil High'),
#  (0.0989579744313892, 'BTC Active Addresses'),
#  (0.0444768174684532, 'vpu_pctChange'),
#  (0.02645150215682722, 'ryu_Adj_Close'),
#  (0.01444341745676303, 'BTC Daily Transactions Change (%)'),
#  (0.006237421745546641, 'Nat Gas pctChange'),
#  (0.005946490139676449, 'icln_pctChange'),
#  (0.003708124855004301, 'xlu_pctChange'),
#  (0.0022712205397565563, 'Crude Oil pctChange'),
#  (0.0019213367395900622, 'BTC New Coins Mined'),
#  (0.0018194105061285, 'BTC New Coins Mined (%)'),
#  (-0.0017525792078538491, 'BTC Daily Volume Change (%)'),
#  (-0.008417554639057556, 'BTC Volume'),
#  (-0.01087723803619882, 'BTC Daily Active Addresses Change (%)'),
#  (-0.01637114893505258, 'ryu_pctChange'),
#  (-0.02765912105803443, 'temp_diff'),
#  (-0.05329562750133484, 'futy_pctChange'),
#  (-0.09277754738641696, 'BTC Transactions'),
#  (-0.0945883036023277, 'Nat Gas Low'),
#  (-0.19495317294712244, 'Nat Gas Adj Close'),
#  (-0.49246338628766667, 'Crude Oil Low'),
#  (-2.84224055553386, 'vpu_Adj_Close')]

# %%
importances_df =pd.DataFrame(sorted(zip(importances, X.columns), reverse=True))
importances_df
# Out:
#            0                                      1
# 0   2.316818                         futy_Adj_Close
# 1   0.711577                         icln_Adj_Close
# 2   0.503084                          xlu_Adj_Close
# 3   0.370375                    Crude Oil Adj Close
# 4   0.295311                           Nat Gas High
# 5   0.201799                         Crude Oil High
# 6   0.098958                   BTC Active Addresses
# 7   0.044477                          vpu_pctChange
# 8   0.026452                          ryu_Adj_Close
# 9   0.014443      BTC Daily Transactions Change (%)
# 10  0.006237                      Nat Gas pctChange
# 11  0.005946                         icln_pctChange
# 12  0.003708                          xlu_pctChange
# 13  0.002271                    Crude Oil pctChange
# 14  0.001921                    BTC New Coins Mined
# 15  0.001819                BTC New Coins Mined (%)
# 16 -0.001753            BTC Daily Volume Change (%)
# 17 -0.008418                             BTC Volume
# 18 -0.010877  BTC Daily Active Addresses Change (%)
# 19 -0.016371                          ryu_pctChange
# 20 -0.027659                              temp_diff
# 21 -0.053296                         futy_pctChange
# 22 -0.092778                       BTC Transactions
# 23 -0.094588                            Nat Gas Low
# 24 -0.194953                      Nat Gas Adj Close
# 25 -0.492463                          Crude Oil Low
# 26 -2.842241                          vpu_Adj_Close

# %%
# Visualize the features by importance
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <AxesSubplot:title={'center':'Features Importances'}, ylabel='1'>

# %%
# Making predictions using the testing data
predictions = model.predict(X_test)
predictions
# Out:
# array([ 8.59671217,  8.59790928,  8.43612575,  8.38331487,  8.42521989,
#         8.55004405,  8.44268366,  8.44507598,  8.31361987,  8.20748937,
#         8.12782819,  8.02676848,  7.75891317,  8.00729165,  7.91202138,
#         7.95995515,  8.01141829,  8.12353247,  7.9608969 ,  8.15169554,
#         8.26955715,  8.31701781,  8.4327715 ,  8.46726539,  8.58964063,
#         8.58480944,  8.48044326,  8.55002823,  8.63398008,  8.60294963,
#         8.58336531,  8.60940233,  8.73492418,  8.82043904,  8.7302961 ,
#         8.83043869,  8.8923925 ,  9.06627273,  9.13983122,  8.97334066,
#         9.00251795,  9.02308131,  8.91817336,  8.885572  ,  9.04513061,
#         9.18676802,  9.15332099,  9.15467781,  9.10389477,  9.2073915 ,
#         9.2162034 ,  9.2113571 ,  9.27968763,  9.34058034,  9.36245914,
#         9.31362391,  9.23227089,  9.26945311,  9.26931746,  9.41229089,
#         9.34604005,  9.18869631,  9.18039988,  9.32073941,  9.391762  ,
#         9.51681926,  9.41421466,  9.37494466,  9.53943055,  9.49865074,
#         9.52629221,  9.35517304,  9.24987715,  9.19479098,  9.25781954,
#         9.19472593,  9.30108654,  9.26793774,  9.43423866,  9.46552422,
#         9.45795924,  9.55781279,  9.68856425,  9.59420759,  9.57653867,
#         9.6599626 ,  9.55500372,  9.512709  ,  9.56986636,  9.64097213,
#         9.65703969,  9.56898766,  9.60413189,  9.67224832,  9.60657371,
#         9.57478913,  9.63418298,  9.63661236,  9.66818402,  9.66426685,
#        21.36366855, 21.93491301, 21.40062771, 21.73642124, 21.79729157,
#        22.1050513 , 23.0350805 , 23.11118111, 23.51894569, 23.92070698,
#        24.30828363, 25.04253103, 25.48153071, 25.51382313, 25.34840973,
#        25.91592367, 25.80314329, 26.29566671, 26.80887536, 28.59427663,
#        30.35719444, 30.13167573, 29.21543288, 29.55605057, 29.59172547,
#        29.40761246, 27.82949463, 28.63137775, 28.48550446, 29.76453395,
#        29.93163962, 29.57163688, 29.34063153, 27.54348412, 28.08304767,
#        27.31673091, 27.86480512, 28.17433804, 28.63780197, 28.24912305,
#        28.48642227, 28.84426841, 28.48511457, 28.13294531, 28.30898158,
#        27.76989126, 27.41621535])

# %%
Results = y_test
Out_of_sample_results = pd.DataFrame({"Actual_Results": y_test,
                   "Predicted Returns": predictions})

# %%
Out_of_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
Out_of_sample_results.head()
# Out:
#             Actual_Results  Predicted Returns
# 2018-12-04        8.426331           8.596712
# 2018-12-06        8.224329           8.597909
# 2018-12-07        8.180505           8.436126
# 2018-12-10        8.083118           8.383315
# 2018-12-11        7.995470           8.425220

# %%
#out of sample performance
out_of_sample_mse = mean_squared_error(
    Out_of_sample_results["Actual_Results"],
    Out_of_sample_results["Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

out_of_sample_rmse = np.sqrt(out_of_sample_mse)
r2 = r2_score(Out_of_sample_results["Actual_Results"], Out_of_sample_results["Predicted Returns"])

print(f"Out-of-sample Root Mean Squared Error (RMSE): {out_of_sample_rmse}")
print(f"Out-of-Sample r2: {r2}")
# Out:
# Out-of-sample Root Mean Squared Error (RMSE): 1.5210140342946206
# Out-of-Sample r2: 0.9370227820992698

# %%
Out_of_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
#In sample performance

in_sample_results = y_train

# Add a column of "in-sample" predictions to that dataframe:  
# YOUR CODE HERE!

in_sample_results = pd.DataFrame({"Actual_Results": y_train})

in_sample_results["in-sample predictions"] = model.predict(X_train)


# Calculate in-sample mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_mse = mean_squared_error(
    in_sample_results["Actual_Results"],
    in_sample_results["in-sample predictions"]
)

# Calculate in-sample root mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!

in_sample_rmse = np.sqrt(in_sample_mse)
r2_in = r2_score(in_sample_results["Actual_Results"], in_sample_results["in-sample predictions"])
print(f"In Sample Root Mean Squared Error (RMSE): {in_sample_rmse}")
print(f"In sample r2: {r2_in}")
# Out:
# In Sample Root Mean Squared Error (RMSE): 0.2775071123253775
# In sample r2: 0.8838138258325835

# %%
in_sample_results.plot()
# Out:
# <AxesSubplot:>

# %%
#AutoRegressor library components
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std

# %%
#Recursive Feature Elimination logic
rfe = RFE(estimator=DecisionTreeRegressor(), n_features_to_select=5)
pipeline = Pipeline(steps=[('s',rfe),('m',model)])

# %%
#Evaluate Model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')

# %%
#RFE performance. MAE = Mean Absolute Error
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MAE: -0.216 (0.016)

# %%
#re-running model with recursive feature elimination prediction
pipeline.fit(X_train, y_train)
yhat = pipeline.predict(X_test)

# %%
oos_pipeline_results = pd.DataFrame({"Actual_Results": y_test,
                   "Pipeline Predicted Returns": yhat})

# %%
oos_pipeline_results.head()
# Out:
#             Actual_Results  Pipeline Predicted Returns
# 2018-12-04        8.426331                    8.656657
# 2018-12-06        8.224329                    8.650089
# 2018-12-07        8.180505                    8.476846
# 2018-12-10        8.083118                    8.448951
# 2018-12-11        7.995470                    8.431418

# %%
#out of sample PIPELINE  performance
oos_pipeline_mse = mean_squared_error(
    oos_pipeline_results["Actual_Results"],
    oos_pipeline_results["Pipeline Predicted Returns"]
)

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

oos_pipeline_mse = np.sqrt(oos_pipeline_mse)
r2 = r2_score(oos_pipeline_results["Actual_Results"], oos_pipeline_results["Pipeline Predicted Returns"])

print(f"Out-of-sample Pipeline Root Mean Squared Error (RMSE): {oos_pipeline_mse}")
print(f"Out-of-Sample Pipeline r2: {r2}")
# Out:
# Out-of-sample Pipeline Root Mean Squared Error (RMSE): 1.3578183049298116
# Out-of-Sample Pipeline r2: 0.9498119471126469

# %%
oos_pipeline_results.plot()
# Out:
# <AxesSubplot:>

# %%
#Which features were selected
for i in range(X_train.shape[1]):
	print('Column: %d. Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0. Selected False, Rank: 9.000
# Column: 1. Selected False, Rank: 7.000
# Column: 2. Selected False, Rank: 13.000
# Column: 3. Selected False, Rank: 15.000
# Column: 4. Selected False, Rank: 20.000
# Column: 5. Selected False, Rank: 3.000
# Column: 6. Selected False, Rank: 11.000
# Column: 7. Selected False, Rank: 6.000
# Column: 8. Selected False, Rank: 16.000
# Column: 9. Selected True, Rank: 1.000
# Column: 10. Selected False, Rank: 18.000
# Column: 11. Selected False, Rank: 14.000
# Column: 12. Selected False, Rank: 23.000
# Column: 13. Selected False, Rank: 5.000
# Column: 14. Selected False, Rank: 22.000
# Column: 15. Selected True, Rank: 1.000
# Column: 16. Selected False, Rank: 21.000
# Column: 17. Selected False, Rank: 17.000
# Column: 18. Selected False, Rank: 12.000
# Column: 19. Selected True, Rank: 1.000
# Column: 20. Selected False, Rank: 2.000
# Column: 21. Selected False, Rank: 8.000
# Column: 22. Selected False, Rank: 10.000
# Column: 23. Selected True, Rank: 1.000
# Column: 24. Selected True, Rank: 1.000
# Column: 25. Selected False, Rank: 4.000
# Column: 26. Selected False, Rank: 19.000

# %%
X.columns
# Out:
# Index(['temp_diff', 'BTC Volume', 'BTC Daily Volume Change (%)',
#        'BTC New Coins Mined', 'BTC New Coins Mined (%)',
#        'BTC Active Addresses', 'BTC Daily Active Addresses Change (%)',
#        'BTC Transactions', 'BTC Daily Transactions Change (%)',
#        'icln_Adj_Close', 'icln_pctChange', 'xlu_Adj_Close', 'xlu_pctChange',
#        'vpu_Adj_Close', 'vpu_pctChange', 'ryu_Adj_Close', 'ryu_pctChange',
#        'futy_Adj_Close', 'futy_pctChange', 'Nat Gas High', 'Nat Gas Low',
#        'Nat Gas Adj Close', 'Nat Gas pctChange', 'Crude Oil High',
#        'Crude Oil Low', 'Crude Oil Adj Close', 'Crude Oil pctChange'],
#       dtype='object')
